# %%
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Reshape, LSTM, LeakyReLU
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.metrics import confusion_matrix
from scipy.stats import multivariate_normal
import math
import os
import random
import pickle
import tensorflow as tf
#which gpu is available?
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
path='results/cicids/all_features/'

# %%
#block to get reproducible results
seed_value=1
os.environ['PYTHONHASHSEED']=str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
#import dataset
dataset=pd.read_csv('../../MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv')
dataset_1=pd.read_csv('../../MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv')
dataset_2=pd.read_csv('../../MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')
dataset_3=pd.read_csv('../../MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')
dataset_4=pd.read_csv('../../MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')
dataset_5=pd.read_csv('../../MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')
dataset_6=pd.read_csv('../../MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv')
dataset_7=pd.read_csv('../../MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv')

# %%
dataset=dataset.append(dataset_1, ignore_index=True)
dataset=dataset.append(dataset_2, ignore_index=True)
dataset=dataset.append(dataset_3, ignore_index=True)
dataset=dataset.append(dataset_4, ignore_index=True)
dataset=dataset.append(dataset_5, ignore_index=True)
dataset=dataset.append(dataset_6, ignore_index=True)
dataset=dataset.append(dataset_7, ignore_index=True)

# %%
dataset.head()
dataset[dataset==np.inf]=np.nan
dataset.fillna(0,inplace=True)
x_dataset=dataset.iloc[:, :-1]
y=dataset.iloc[:, -1]

# %%
le=LabelEncoder()
y_encoded=le.fit_transform(y)
# le.classes_

# %%
scaler=MinMaxScaler()
x_dataset_scaled=scaler.fit_transform(x_dataset)

# %%
def to_onehot(yy):
    yy1 = np.zeros([len(yy), max(yy)+1])
    yy1[np.arange(len(yy)),yy] = 1
    return yy1

# %%
#FIND OUT INDICES OF Y AND X THAT ARE ONLY NORMAL AND DIVIDE intow two parts
y_normal_indices=np.where(y_encoded==0)
y_normal_indices_list=np.array_split(y_normal_indices[0],2)
y_normal_train=y_encoded[y_normal_indices_list[0]]
y_normal_test=y_encoded[y_normal_indices_list[1]]
x_normal_train=x_dataset_scaled[y_normal_indices_list[0]]
x_normal_test=x_dataset_scaled[y_normal_indices_list[1]]
print(len(y_normal_train), len(y_normal_test), len(x_normal_train), len(x_normal_test))
# Out:
# 1136549 1136548 1136549 1136548

# %%
y_val,y_count = np.unique(y_encoded, return_counts=True) 
y_retained = y_val[y_count>100]
y_attacks = y_retained[y_retained>0]

accs = []
cfs = []
y_attacks
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7, 10, 11, 12, 14])

# %%
for n_attacks_train in y_attacks:
    #find the training attacks
    y_train_indices=np.where(y_encoded==n_attacks_train)

    y_attack_train=np.ones(len(y_train_indices[0]),dtype=int)  
    #find the x_dataset corr to this
    x_attack_train=x_dataset_scaled[y_train_indices[0]]
    
    
    #create the training data
    x_train=np.concatenate([x_attack_train,x_normal_train])
    y_train=np.concatenate([y_attack_train,y_normal_train])
    
    print("Length of y_attack_test",len(y_attack_train))
    n=(int)(len(y_normal_train)/len(y_attack_train))
    print(n)
    # X_train, Y_train=get_train_data(n_attacks_train, bootstrap)
    #if bootstrap:
        
    for i in range(n-1):
        x_train=np.concatenate([x_train,x_attack_train])
        y_train=np.concatenate([y_train,y_attack_train])
        
    print("XTRAIN_TRAINLEN", len(x_train),len(y_train))
    
    # Need to declare it every time, otherwise it gets erased from memory
    def cldnn():
          #FILL THIS IN WITH MODEL ARCHITECTURE
        model = Sequential()
        model.add(Conv2D(256,(1,3),activation="relu",input_shape =(2,39,1)))
        model.add(Conv2D(256,(2,3),activation=None))
        model.add(LeakyReLU(0.3))
        model.add(Conv2D(256,(1,3),activation=None))
        model.add(LeakyReLU(0.3))
        model.add(Dropout(0.20))
        model.add(Conv2D(80,(1,3),activation="relu"))
        model.add(Reshape((31,80)))
        model.add(Flatten())
        model.add(Dense(128,activation="relu",kernel_initializer="normal"))
        model.add(Dense(2,activation="sigmoid"))
        model.summary()
        return model
        
    cldnn = cldnn()
    cldnn.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
    
    x_train_examples,_=x_train.shape
    Y_train = to_onehot(y_train)
    X_train = x_train.reshape(x_train_examples, 2, 39, 1)
        
    cldnn_mdata=cldnn.fit(X_train,Y_train,validation_split=0.2,epochs=20,batch_size =1024,shuffle=True)
    
    if not os.path.exists(path+f'weights/{n_attacks_train}'):
        os.makedirs(path+f'weights/{n_attacks_train}')
    
    cldnn.save(path+f'weights/{n_attacks_train}/weights.h5')
    
    for n_attacks_test in y_attacks:
        print(n_attacks_train, n_attacks_test)

        #find the testing attacks
        if n_attacks_test== n_attacks_train:
            continue
        
        y_test_indices=np.where(y_encoded==n_attacks_test)
        y_test_indices=y_test_indices[0] 
        
        y_attack_test=np.ones(len(y_test_indices),dtype=int)
        
        print(len(x_train),len(y_train[y_train==0]),len(y_train[y_train==1]))
            
        #find the x_dataset corr to this
        x_attack_test=x_dataset_scaled[y_test_indices]

        #create the testing data
        x_test=np.concatenate([x_attack_test,x_normal_test])
        y_test=np.concatenate([y_attack_test,y_normal_test])   
    
        #print("TRAINING", len(y_train),len(y_train[y_train==0]), len(y_train[y_train==1]))
        #print("TESTING", len(y_test),len(y_test[y_test==0]), len(y_test[y_test==1]))   
        
        x_test_examples,_= x_test.shape
                
        
        Y_test = to_onehot(y_test)
        X_test = x_test.reshape(x_test_examples, 2, 39, 1)
        
        X_test, Y_test=dataloader.get_test_data(n_attacks_test)

        scores=cldnn.evaluate(X_test,Y_test)
        
        print(n_attacks_train, n_attacks_test)
        print("Accuracy:%.2f%%"%(scores[1]*100))
        
        accs.append(scores[1])
        
        y_pred=cldnn.predict(X_test)
        y_label=np.argmax(y_pred,axis=-1)
        cf=confusion_matrix(y_test,y_label)
        
        cfs.append(cf)
# Out:
# Length of y_attack_test 1966
# 578
# XTRAIN_TRAINLEN 2272897 2272897
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape (Reshape)            (None, 31, 80)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 2480)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               317568
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1776/1776 [==============================] - 77s 43ms/step - loss: 0.1382 - accuracy: 0.9429 - val_loss: 0.0178 - val_accuracy: 0.9990
# Epoch 2/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0386 - accuracy: 0.9891 - val_loss: 0.0135 - val_accuracy: 0.9990
# Epoch 3/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0386 - accuracy: 0.9874 - val_loss: 0.0056 - val_accuracy: 0.9990
# Epoch 4/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.
20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 3.6950e-04 - accuracy: 0.9999 - val_loss: 1.5512e-04 - val_accuracy: 1.0000
# 3 1
# 2268779 1136549 1132230
# 35579/35579 [==============================] - 84s 2ms/step - loss: 0.3547 - accuracy: 0.9982
# 3 1
# Accuracy:99.82%
# 3 2
# 2268779 1136549 1132230
# 39518/39518 [==============================] - 94s 2ms/step - loss: 2.3811 - accuracy: 0.9022
# 3 2
# Accuracy:90.22%
# 3 3
# 3 4
# 2268779 1136549 1132230
# 42739/42739 [==============================] - 101s 2ms/step - loss: 6.0521 - accuracy: 0.8311
# 3 4
# Accuracy:83.11%
# 3 5
# 2268779 1136549 1132230
# 35689/35689 [==============================] - 85s 2ms/step - loss: 0.1573 - accuracy: 0.9977
# 3 5
# Accuracy:99.77%
# 3 6
# 2268779 1136549 1132230
# 35699/35699 [==============================] - 86s 2ms/step - loss: 0.1983 - accuracy: 0.9963
# 3 6
# Accuracy:99.63%
# 3 7
# 2268779 1136549 1132230
# 35766/35766 [==============================] - 85s 2ms/step - loss: 0.3276 - accuracy: 0.9930
# 3 7
# Accuracy:99.30%
# 3 10
# 2268779 1136549 1132230
# 40484/40484 [==============================] - 97s 2ms/step - loss: 17.6726 - accuracy: 0.8773
# 3 10
# Accuracy:87.73%
# 3 11
# 2268779 1136549 1132230
# 35702/35702 [==============================] - 84s 2ms/step - loss: 0.4005 - accuracy: 0.9948
# 3 11
# Accuracy:99.48%
# 3 12
# 2268779 1136549 1132230
# 35565/35565 [==============================] - 85s 2ms/step - loss: 0.1434 - accuracy: 0.9986
# 3 12
# Accuracy:99.86%
# 3 14
# 2268779 1136549 1132230
# 35538/35538 [==============================] - 83s 2ms/step - loss: 0.0612 - accuracy: 0.9994
# 3 14
# Accuracy:99.94%
# Length of y_attack_test 231073
# 4
# XTRAIN_TRAINLEN 2060841 2060841
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               317568
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1611/1611 [==============================] - 69s 42ms/step - loss: 0.0770 - accuracy: 0.9640 - val_loss: 0.0395 - val_accuracy: 0.9989
# Epoch 2/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.0088 - val_accuracy: 0.9992
# Epoch 3/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.0040 - val_accuracy: 0.9999
# Epoch 4/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0116 - accuracy: 0.9956 - val_loss: 0.0056 - val_accuracy: 0.9996
# Epoch 5/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.0045 - val_accuracy: 0.9987
# Epoch 6/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0079 - val_accuracy: 0.9979
# Epoch 7/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0122 - val_accuracy: 0.9971
# Epoch 8/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.0110 - val_accuracy: 0.9978
# Epoch 9/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0040 - val_accuracy: 0.9991
# Epoch 10/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0134 - val_accuracy: 0.9963
# Epoch 11/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0098 - val_accuracy: 0.9976
# Epoch 12/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0045 - val_accuracy: 0.9987
# Epoch 13/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0184 - val_accuracy: 0.9971
# Epoch 14/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0070 - val_accuracy: 0.9985
# Epoch 15/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0083 - val_accuracy: 0.9981
# Epoch 16/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0053 - val_accuracy: 0.9984
# Epoch 17/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0117 - val_accuracy: 0.9975
# Epoch 18/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0065 - val_accuracy: 0.9983
# Epoch 19/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0086 - val_accuracy: 0.9977
# Epoch 20/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0
20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0027 - val_accuracy: 0.9991
# 6 1
# 2272565 1136549 1136016
# 35579/35579 [==============================] - 84s 2ms/step - loss: 0.2415 - accuracy: 0.9980
# 6 1
# Accuracy:99.80%
# 6 2
# 2272565 1136549 1136016
# 39518/39518 [==============================] - 94s 2ms/step - loss: 2.0812 - accuracy: 0.8985
# 6 2
# Accuracy:89.85%
# 6 3
# 2272565 1136549 1136016
# 35839/35839 [==============================] - 85s 2ms/step - loss: 0.1031 - accuracy: 0.9929
# 6 3
# Accuracy:99.29%
# 6 4
# 2272565 1136549 1136016
# 42739/42739 [==============================] - 102s 2ms/step - loss: 2.8148 - accuracy: 0.8311
# 6 4
# Accuracy:83.11%
# 6 5
# 2272565 1136549 1136016
# 35689/35689 [==============================] - 85s 2ms/step - loss: 0.0078 - accuracy: 0.9993
# 6 5
# Accuracy:99.93%
# 6 6
# 6 7
# 2272565 1136549 1136016
# 35766/35766 [==============================] - 85s 2ms/step - loss: 0.0771 - accuracy: 0.9928
# 6 7
# Accuracy:99.28%
# 6 10
# 2272565 1136549 1136016
# 40484/40484 [==============================] - 96s 2ms/step - loss: 16.3274 - accuracy: 0.8771
# 6 10
# Accuracy:87.71%
# 6 11
# 2272565 1136549 1136016
# 35702/35702 [==============================] - 86s 2ms/step - loss: 0.1147 - accuracy: 0.9946
# 6 11
# Accuracy:99.46%
# 6 12
# 2272565 1136549 1136016
# 35565/35565 [==============================] - 85s 2ms/step - loss: 0.0084 - accuracy: 0.9985
# 6 12
# Accuracy:99.85%
# 6 14
# 2272565 1136549 1136016
# 35538/35538 [==============================] - 85s 2ms/step - loss: 0.0035 - accuracy: 0.9992
# 6 14
# Accuracy:99.92%
# Length of y_attack_test 7938
# 143
# XTRAIN_TRAINLEN 2271683 2271683
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_6 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               317568
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1775/1775 [==============================] - 76s 43ms/step - loss: 0.0555 - accuracy: 0.9787 - val_loss: 0.0066 - val_accuracy: 0.9977
# Epoch 2/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0162 - accuracy: 0.9984 - val_loss: 0.0062 - val_accuracy: 0.9977
# Epoch 3/20
# 1775/1775 [==============================] - 74s 42ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0025 - val_accuracy: 0.9991
# Epoch 4/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0016 - val_accuracy: 0.9991
# Epoch 5/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 0.9991
# Epoch 6/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0016 - val_accuracy: 0.9991
# Epoch 7/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0017 - val_accuracy: 0.9991
# Epoch 8/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0014 - val_accuracy: 0.9991
# Epoch 9/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 8.6716e-04 - accuracy: 0.9997 - val_loss: 4.9214e-04 - val_accuracy: 0.9999
# Epoch 10/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 7.4410e-04 - accuracy: 0.9998 - val_loss: 0.0012 - val_accuracy: 0.9991
# Epoch 11/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 7.5603e-04 - accuracy: 0.9998 - val_loss: 8.4363e-04 - val_accuracy: 0.9999
# Epoch 12/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 5.9856e-04 - accuracy: 0.9998 - val_loss: 0.0017 - val_accuracy: 0.9991
# Epoch 13/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 6.4828e-04 - accuracy: 0.9998 - val_loss: 9.2603e-04 - val_accuracy: 0.9999
# Epoch 14/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 4.5468e-04 - accuracy: 0.9999 - val_loss: 4.9155e-04 - val_accuracy: 0.9999
# Epoch 15/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 5.2371e-04 - accuracy: 0.9998 - val_loss: 0.0013 - val_accuracy: 0.9991
# Epoch 16/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 5.0257e-04 - accuracy: 0.9998 - val_loss: 2.9974e-04 - val_accuracy: 0.9999
# Epoch 17/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 4.8087e-04 - accuracy: 0.9998 - val_loss: 5.6269e-04 - val_accuracy: 0.9999
# Epoch 18/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 5.1131e-04 - accuracy: 0.9998 - val_loss: 8.7417e-04 - val_accuracy: 0.9999
# Epoch 19/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 5.4146e-04 - accuracy: 0.9998 - val_loss: 5.6073e-04 - val_accuracy: 0.9999
# Epoch 20/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 4.0966e-04 - accuracy: 0.9999 - val_loss: 3.8641e-04 - val_accuracy: 0.9999
# 7 1
# 2271683 1136549 1135134
# 35579/35579 [==============================] - 85s 2ms/step - loss: 0.4254 - accuracy: 0.9983
# 7 1
# Accuracy:99.83%
# 7 2
# 2271683 1136549 1135134
# 39518/39518 [==============================] - 95s 2ms/step - loss: 3.9350 - accuracy: 0.8987
# 7 2
# Accuracy:89.87%
# 7 3
# 2271683 1136549 1135134
# 35839/35839 [==============================] - 85s 2ms/step - loss: 0.4792 - accuracy: 0.9910
# 7 3
# Accuracy:99.10%
# 7 4
# 2271683 1136549 1135134
# 42739/42739 [==============================] - 98s 2ms/step - loss: 8.7164 - accuracy: 0.8310
# 7 4
# Accuracy:83.10%
# 7 5
# 2271683 1136549 1135134
# 35689/35689 [==============================] - 85s 2ms/step - loss: 0.2221 - accuracy: 0.9952
# 7 5
# Accuracy:99.52%
# 7 6
# 2271683 1136549 1135134
# 35699/35699 [==============================] - 82s 2ms/step - loss: 0.2533 - accuracy: 0.9949
# 7 6
# Accuracy:99.49%
# 7 7
# 7 10
# 2271683 1136549 1135134
# 40484/40484 [==============================] - 92s 2ms/step - loss: 27.5727 - accuracy: 0.8773
# 7 10
# Accuracy:87.73%
# 7 11
# 2271683 1136549 1135134
# 35702/35702 [==============================] - 84s 2ms/step - loss: 0.1589 - accuracy: 0.9948
# 7 11
# Accuracy:99.48%
# 7 12
# 2271683 1136549 1135134
# 35565/35565 [==============================] - 85s 2ms/step - loss: 0.0140 - accuracy: 0.9987
# 7 12
# Accuracy:99.87%
# 7 14
# 2271683 1136549 1135134
# 35538/35538 [==============================] - 83s 2ms/step - loss: 0.0037 - accuracy: 0.9994
# 7 14
# Accuracy:99.94%
# Length of y_attack_test 158930
# 7
# XTRAIN_TRAINLEN 2249059 2249059
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_7 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               317568
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1758/1758 [==============================] - 75s 42ms/step - loss: 0.0476 - accuracy: 0.9832 - val_loss: 0.0040 - val_accuracy: 0.9994
# Epoch 2/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.0037 - val_accuracy: 0.9993
# Epoch 3/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0017 - val_accuracy: 0.9995
# Epoch 4/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0027 - val_accuracy: 0.9995
# Epoch 5/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0018 - val_accuracy: 0.9995
# Epoch 6/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0033 - val_accuracy: 0.9995
# Epoch 7/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0025 - val_accuracy: 0.9994
# Epoch 8/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0022 - val_accuracy: 0.9994
# Epoch 9/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0015 - val_accuracy: 0.9996
# Epoch 10/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0023 - val_accuracy: 0.9994
# Epoch 11/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0020 - val_accuracy: 0.9995
# Epoch 12/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0013 - val_accuracy: 0.9996
# Epoch 13/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 9.5477e-04 - accuracy: 0.9998 - val_loss: 0.0014 - val_accuracy: 0.9996
# Epoch 14/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 9.7962e-04 - val_accuracy: 0.9996
# ...
# Epoch 9/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 6.1554e-04 - val_accuracy: 1.0000
# Epoch 10/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 3.6545e-04 - val_accuracy: 1.0000
# Epoch 11/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 8.9798e-04 - val_accuracy: 0.9998
# Epoch 12/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 0.9997
# Epoch 13/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 2.1254e-04 - val_accuracy: 1.0000
# Epoch 14/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0012 - val_accuracy: 0.9998
# Epoch 15/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 2.2757e-04 - val_accuracy: 1.0000
# Epoch 16/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 3.9925e-04 - val_accuracy: 1.0000
# Epoch 17/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 5.9690e-04 - val_accuracy: 1.0000
# Epoch 18/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0015 - val_accuracy: 0.9995
# Epoch 19/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 5.2913e-04 - val_accuracy: 1.0000
# Epoch 20/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 5.5290e-04 - val_accuracy: 1.0000
# 11 1
# 2268773 1136549 1132224
# 35579/35579 [==============================] - 83s 2ms/step - loss: 0.8924 - accuracy: 0.9982
# 11 1
# Accuracy:99.82%
# 11 2
# 2268773 1136549 1132224
# 39518/39518 [==============================] - 92s 2ms/step - loss: 23.1289 - accuracy: 0.8987
# 11 2
# Accuracy:89.87%
# 11 3
# 2268773 1136549 1132224
# 35839/35839 [==============================] - 85s 2ms/step - loss: 1.8183 - accuracy: 0.9910
# 11 3
# Accuracy:99.10%
# 11 4
# 2268773 1136549 1132224
# 42739/42739 [==============================] - 100s 2ms/step - loss: 38.1274 - accuracy: 0.8310
# 11 4
# Accuracy:83.10%
# 11 5
# 2268773 1136549 1132224
# 35689/35689 [==============================] - 85s 2ms/step - loss: 0.6952 - accuracy: 0.9953
# 11 5
# Accuracy:99.53%
# 11 6
# 2268773 1136549 1132224
# 35699/35699 [==============================] - 85s 2ms/step - loss: 0.7959 - accuracy: 0.9954
# 11 6
# Accuracy:99.54%
# 11 7
# 2268773 1136549 1132224
# 35766/35766 [==============================] - 85s 2ms/step - loss: 0.1838 - accuracy: 0.9965
# 11 7
# Accuracy:99.65%
# 11 10
# 2268773 1136549 1132224
# 40484/40484 [==============================] - 97s 2ms/step - loss: 55.1264 - accuracy: 0.8773
# 11 10
# Accuracy:87.73%
# 11 11
# 11 12
# 2268773 1136549 1132224
# 35565/35565 [==============================] - 84s 2ms/step - loss: 0.2226 - accuracy: 0.9986
# 11 12
# Accuracy:99.86%
# 11 14
# 2268773 1136549 1132224
# 35538/35538 [==============================] - 84s 2ms/step - loss: 0.1040 - accuracy: 0.9994
# 11 14
# Accuracy:99.94%
# Length of y_attack_test 1507
# 754
# XTRAIN_TRAINLEN 2272827 2272827
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_9 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               317568
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1776/1776 [==============================] - 76s 42ms/step - loss: 0.0781 - accuracy: 0.9678 - val_loss: 0.0104 - val_accuracy: 0.9993
# Epoch 2/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0195 - accuracy: 0.9955 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 3/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.
# 14 10
# 2272985 1136549 1136436
# 40484/40484 [==============================] - 96s 2ms/step - loss: 52.4770 - accuracy: 0.8771
# 14 10
# Accuracy:87.71%
# 14 11
# 2272985 1136549 1136436
# 35702/35702 [==============================] - 84s 2ms/step - loss: 0.0432 - accuracy: 0.9946
# 14 11
# Accuracy:99.46%
# 14 12
# 2272985 1136549 1136436
# 35565/35565 [==============================] - 85s 2ms/step - loss: 0.0035 - accuracy: 0.9996
# 14 12
# Accuracy:99.96%
# 14 14

# %%
# Name of pickle file to be saved
outname = 'conf_matrix_basearch_all_full_balanced.pickle'

#outfile = os.path.join(os.getcwd(), outname)
if os.path.exists(path+outname):
        os.replace(path+outname, path+outname + ".old")
        
with open(path+outname, 'wb') as file:
    pickle.dump(cfs, file)

# %%
cfs
# Out:
# [array([[1120458,   16090],
#         [ 128027,       0]]),
#  array([[1120458,   16090],
#         [  10293,       0]]),
#  array([[1120458,   16090],
#         [ 231073,       0]]),
#  array([[1120458,   16090],
#         [   5499,       0]]),
#  array([[1120458,   16090],
#         [   5796,       0]]),
#  array([[1120458,   16090],
#         [   7938,       0]]),
#  array([[1120458,   16090],
#         [  90767,   68163]]),
#  array([[1120458,   16090],
#         [   5897,       0]]),
#  array([[1120458,   16090],
#         [   1507,       0]]),
#  array([[1120458,   16090],
#         [    652,       0]]),
#  array([[1136301,     247],
#         [   1966,       0]]),
#  array([[1136301,     247],
#         [   9849,     444]]),
#  array([[1136301,     247],
#         [ 193013,   38060]]),
#  array([[1136301,     247],
#         [   5499,       0]]),
#  array([[1136301,     247],
#         [   5795,       1]]),
#  array([[1136301,     247],
#         [   7938,       0]]),
#  array([[1136301,     247],
#         [ 158847,      83]]),
#  array([[1136301,     247],
#         [   5897,       0]]),
#  array([[1136301,     247],
#         [   1507,       0]]),
#  array([[1136301,     247],
#         [    652,       0]]),
#  array([[1136460,      88],
#         [   1966,       0]]),
#  array([[1136460,      88],
#         [ 123559,    4468]]),
#  array([[1136460,      88],
#         [ 230902,     171]]),
#  array([[1136460,      88],
#         [   2563,    2936]]),
#  array([[1136460,      88],
#         [   4128,    1668]]),
#  array([[1136460,      88],
#         [   7938,       0]]),
#  array([[1136460,      88],
#         [ 158901,      29]]),
#  array([[1136460,      88],
#         [   5889,       8]]),
#  array([[1136460,      88],
#         [   1507,       0]]),
#  array([[1136460,      88],
#         [    649,       3]]),
#  array([[1135132,    1416],
#         [   1966,       0]]),
#  array([[1135132,    1416],
#         [ 112281,   15746]]),
#  array([[1135132,    1416],
#         [   9435,     858]]),
#  array([[1135132,    1416],
#         [   5499,       0]]),
#  array([[1135132,    1416],
#         [   5794,       2]]),
#  array([[1135132,    1416],
#         [   7938,       0]]),
#  array([[1135132,    1416],
#         [ 158856,      74]]),
#  array([[1135132,    1416],
#         [   5896,       1]]),
#  array([[1135132,    1416],
#         [   1504,       3]]),
#  array([[1135132,    1416],
#         [    652,       0]]),
#  array([[1136385,     163],
#         [   1966,       0]]),
#  array([[1136385,     163],
#         [ 127340,     687]]),
#  array([[1136385,     163],
#         [   8570,    1723]]),
#  array([[1136385,     163],
#         [ 231027,      46]]),
#  array([[1136385,     163],
#         [    836,    4960]]),
#  array([[1136385,     163],
#         [   7938,       0]]),
#  array([[1136385,     163],
#         [ 158922,       8]]),
#  array([[1136385,     163],
#         [   5897,       0]]),
#  array([[1136385,     163],
#         [   1429,      78]]),
#  array([[1136385,     163],
#         [    640,      12]]),
#  array([[1136255,     293],
#         [   1966,       0]]),
#  array([[1136255,     293],
#         [ 128024,       3]]),
#  array([[1136255,     293],
#         [   7905,    2388]]),
#  array([[1136255,     293],
#         [ 230686,     387]]),
#  array([[1136255,     293],
#         [    480,    5019]]),
#  array([[1136255,     293],
#         [   7927,      11]]),
#  array([[1136255,     293],
#         [ 158925,       5]]),
#  array([[1136255,     293],
#         [   5895,       2]]),
#  array([[1136255,     293],
#         [   1431,      76]]),
#  array([[1136255,     293],
#         [    641,      11]]),
#  array([[1136536,      12],
#         [   1966,       0]]),
#  array([[1136536,      12],
#         [ 128027,       0]]),
#  array([[1136536,      12],
#         [  10293,       0]]),
#  array([[1136536,      12],
#         [ 231073,       0]]),
#  array([[1136536,      12],
#         [   5480,      19]]),
#  array([[1136536,      12],
#         [   5793,       3]]),
#  array([[1136536,      12],
#         [ 158930,       0]]),
#  array([[1136536,      12],
#         [   5883,      14]]),
#  array([[1136536,      12],
#         [   1507,       0]]),
#  array([[1136536,      12],
#         [    652,       0]]),
#  array([[1087552,   48996],
#         [   1966,       0]]),
#  array([[1087552,   48996],
#         [ 113873,   14154]]),
#  array([[1087552,   48996],
#         [  10284,       9]]),
#  array([[1087552,   48996],
#         [ 229385,    1688]]),
#  array([[1087552,   48996],
#         [   5499,       0]]),
#  array([[1087552,   48996],
#         [   5796,       0]]),
#  array([[1087552,   48996],
#         [   4047,    3891]]),
#  array([[1087552,   48996],
#         [   5897,       0]]),
#  array([[1087552,   48996],
#         [   1507,       0]]),
#  array([[1087552,   48996],
#         [    652,       0]]),
#  array([[1136475,      73],
#         [   1966,       0]]),
#  array([[1136475,      73],
#         [ 128027,       0]]),
#  array([[1136475,      73],
#         [  10293,       0]]),
#  array([[1136475,      73],
#         [ 231073,       0]]),
#  array([[1136475,      73],
#         [   5246,     253]]),
#  array([[1136475,      73],
#         [   5133,     663]]),
#  array([[1136475,      73],
#         [   3976,    3962]]),
#  array([[1136475,      73],
#         [ 158902,      28]]),
#  array([[1136475,      73],
#         [   1507,       0]]),
#  array([[1136475,      73],
#         [    652,       0]]),
#  array([[1136007,     541],
#         [   1966,       0]]),
#  array([[1136007,     541],
#         [ 128027,       0]]),
#  array([[1136007,     541],
#         [  10157,     136]]),
#  array([[1136007,     541],
#         [ 229279,    1794]]),
#  array([[1136007,     541],
#         [   5494,       5]]),
#  array([[1136007,     541],
#         [   5793,       3]]),
#  array([[1136007,     541],
#         [   7926,      12]]),
#  array([[1136007,     541],
#         [ 158918,      12]]),
#  array([[1136007,     541],
#         [   5889,       8]]),
#  array([[1136007,     541],
#         [     39,     613]]),
#  array([[1136229,     319],
#         [   1966,       0]]),
#  array([[1136229,     319],
#         [ 128003,      24]]),
#  array([[1136229,     319],
#         [   5393,    4900]]),
#  array([[1136229,     319],
#         [ 230291,     782]]),
#  array([[1136229,     319],
#         [   5493,       6]]),
#  array([[1136229,     319],
#         [   5788,       8]]),
#  array([[1136229,     319],
#         [   7937,       1]]),
#  array([[1136229,     319],
#         [ 158915,      15]]),
#  array([[1136229,     319],
#         [   5882,      15]]),
#  array([[1136229,     319],
#         [    148,    1359]])]

# %%
with open(path+'conf_matrix_basearch_all_full_balanced.pickle', 'rb') as file:
    cfs = pickle.load(file)

# %%
len(cfs)
# Out:
# 110

# %%
accuracy = []
attack_accuracy = []

for i in range(len(cfs)):
    accuracy.append(np.round(np.trace(cfs[i])/np.sum(cfs[i])*100,2))
    attack_accuracy.append(np.nan_to_num(np.round(cfs[i][1][1]/(cfs[i][0][1]+cfs[i][1][1])*100,2)))

# %%
attacks = [1,2,3,4,5,6,7,10,11,12,14]# Attacks that are retained
# Convert from 1D to 2D
numattacks = len(attacks)
accr = np.zeros((numattacks, numattacks))
attackaccr = np.zeros((numattacks, numattacks))

n = 0

for i in range(numattacks):
    for j in range(numattacks):
        if i == j:
            accr[i][j] = 100
            continue
        else:
            accr[i][j] = accuracy[n]
            attackaccr[i][j] = attack_accuracy[n]
            n = n + 1

# %%
# Create Datafeame and update row/column names
accrd = pd.DataFrame(accr)
ataccrd = pd.DataFrame(attackaccr)

#accrd.columns=accrmat.columns.values
accrd.columns=y_attacks
accrd.index=y_attacks
ataccrd.columns=y_attacks
ataccrd.index=y_attacks

# %%
fig = plt.figure(figsize=(10, 8), dpi=150)

plt.rcParams["font.family"] = "serif"
plt.rc('axes', titlesize=12)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=11)    # legend fontsize
plt.rc('axes', titlesize=15)  # fontsize of the figure title
# create some labels
attack_labels = [ "{0:d}".format(i) for i in attacks ]

# create a color map with random colors
#colmap = matplotlib.colors.ListedColormap(np.random.random((21,3)))
#colmap.colors[0] = [0,0,0]
import seaborn as sns
# this is the real plotting part
ax = fig.add_subplot(111)
sns.heatmap(accrd, linewidths=.5, annot=True, fmt='.2f', cmap='winter', ax=ax)


plt.xlabel('Test Attack')
plt.ylabel('Training Attack')
plt.title('Overall accuracy when training and testing with individual attacks')

plt.show()

# %%
fig = plt.figure(figsize=(10, 8), dpi=150)

plt.rcParams["font.family"] = "serif"
plt.rc('axes', titlesize=12)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=11)    # legend fontsize
plt.rc('axes', titlesize=15)  # fontsize of the figure title
# create some labels
attack_labels = [ "{0:d}".format(i) for i in attacks ]

# create a color map with random colors
#colmap = matplotlib.colors.ListedColormap(np.random.random((21,3)))
#colmap.colors[0] = [0,0,0]

# this is the real plotting part
ax = fig.add_subplot(111)
sns.heatmap(ataccrd, linewidths=.5, annot=True, fmt='.2f', cmap='winter', ax=ax)


plt.xlabel('Test Attack')
plt.ylabel('Training Attack')
plt.title('Attack Accuracy when training and testing with individual attacks (Second Run)')

plt.show()
