# %%
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Reshape, LSTM, LeakyReLU
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.metrics import confusion_matrix
from scipy.stats import multivariate_normal
import math
import os
import random
import pickle
import tensorflow as tf
#which gpu is available?
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
#block to get reproducible results
seed_value=1
os.environ['PYTHONHASHSEED']=str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
#import dataset
dataset=pd.read_csv('../../MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv')
dataset_1=pd.read_csv('../../MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv')
dataset_2=pd.read_csv('../../MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')
dataset_3=pd.read_csv('../../MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')
dataset_4=pd.read_csv('../../MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')
dataset_5=pd.read_csv('../../MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')
dataset_6=pd.read_csv('../../MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv')
dataset_7=pd.read_csv('../../MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv')

# %%
dataset=dataset.append(dataset_1, ignore_index=True)
dataset=dataset.append(dataset_2, ignore_index=True)
dataset=dataset.append(dataset_3, ignore_index=True)
dataset=dataset.append(dataset_4, ignore_index=True)
dataset=dataset.append(dataset_5, ignore_index=True)
dataset=dataset.append(dataset_6, ignore_index=True)
dataset=dataset.append(dataset_7, ignore_index=True)

# %%
dataset.head()
dataset[dataset==np.inf]=np.nan
dataset.fillna(0,inplace=True)
x_dataset=dataset.iloc[:, :-1]
y=dataset.iloc[:, -1]

# %%
le=LabelEncoder()
y_encoded=le.fit_transform(y)
# le.classes_

# %%
scaler=MinMaxScaler()
x_dataset_scaled=scaler.fit_transform(x_dataset)

# %%
def to_onehot(yy):
    yy1 = np.zeros([len(yy), max(yy)+1])
    yy1[np.arange(len(yy)),yy] = 1
    return yy1

# %%
#FIND OUT INDICES OF Y AND X THAT ARE ONLY NORMAL AND DIVIDE intow two parts
y_normal_indices=np.where(y_encoded==0)
y_normal_indices_list=np.array_split(y_normal_indices[0],2)
y_normal_train=y_encoded[y_normal_indices_list[0]]
y_normal_test=y_encoded[y_normal_indices_list[1]]
x_normal_train=x_dataset_scaled[y_normal_indices_list[0]]
x_normal_test=x_dataset_scaled[y_normal_indices_list[1]]
print(len(y_normal_train), len(y_normal_test), len(x_normal_train), len(x_normal_test))
# Out:
# 1136549 1136548 1136549 1136548

# %%
y_val,y_count = np.unique(y_encoded, return_counts=True) 
y_retained = y_val[y_count>100]
y_attacks = y_retained[y_retained>0]

accs = []
cfs = []
y_attacks
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7, 10, 11, 12, 14])

# %%
for n_attacks_train in y_attacks:
    #find the training attacks
    y_train_indices=np.where(y_encoded==n_attacks_train)

    y_attack_train=np.ones(len(y_train_indices[0]),dtype=int)  
    #find the x_dataset corr to this
    x_attack_train=x_dataset_scaled[y_train_indices[0]]
    
    
    #create the training data
    x_train=np.concatenate([x_attack_train,x_normal_train])
    y_train=np.concatenate([y_attack_train,y_normal_train])
    
    print("Length of y_attack_test",len(y_attack_train))
    n=(int)(len(y_normal_train)/len(y_attack_train))
    print(n)
    for i in range(n-1):
        x_train=np.concatenate([x_train,x_attack_train])
        y_train=np.concatenate([y_train,y_attack_train])
        
    print("XTRAIN_TRAINLEN", len(x_train),len(y_train))
    
    # Need to declare it every time, otherwise it gets erased from memory
    def cldnn():
          #FILL THIS IN WITH MODEL ARCHITECTURE
        model = Sequential()
        model.add(Conv2D(256,(1,3),activation="relu",input_shape =(2,39,1)))
        model.add(Conv2D(256,(2,3),activation=None))
        model.add(LeakyReLU(0.3))
        model.add(Conv2D(256,(1,3),activation=None))
        model.add(LeakyReLU(0.3))
        model.add(Dropout(0.20))
        model.add(Conv2D(80,(1,3),activation="relu"))
        model.add(Reshape((31,80)))
        model.add(Flatten())
        model.add(Dense(128,activation="relu",kernel_initializer="normal"))
        model.add(Dense(2,activation="sigmoid"))
        model.summary()
        return model
        
    cldnn = cldnn()
    cldnn.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
    
    x_train_examples,_=x_train.shape
    Y_train = to_onehot(y_train)
    X_train = x_train.reshape(x_train_examples, 2, 39, 1)
        
    cldnn_mdata=cldnn.fit(X_train,Y_train,validation_split=0.2,epochs=20,batch_size =1024,shuffle=True)
    
    for n_attacks_test in y_attacks:
        print(n_attacks_train, n_attacks_test)

        #find the testing attacks
        if n_attacks_test== n_attacks_train:
            continue
        else:
            y_test_indices=np.where(y_encoded==n_attacks_test)
            y_test_indices=y_test_indices[0] 
        
        y_attack_test=np.ones(len(y_test_indices),dtype=int)
        
        print(len(x_train),len(y_train[y_train==0]),len(y_train[y_train==1]))
            
        #find the x_dataset corr to this
        x_attack_test=x_dataset_scaled[y_test_indices]

        #create the testing data
        x_test=np.concatenate([x_attack_test,x_normal_test])
        y_test=np.concatenate([y_attack_test,y_normal_test])   
    
        #print("TRAINING", len(y_train),len(y_train[y_train==0]), len(y_train[y_train==1]))
        #print("TESTING", len(y_test),len(y_test[y_test==0]), len(y_test[y_test==1]))   
        
        
        x_test_examples,_= x_test.shape
                
        
        Y_test = to_onehot(y_test)
        X_test = x_test.reshape(x_test_examples, 2, 39, 1)

        scores=cldnn.evaluate(X_test,Y_test)
        
        print(n_attacks_train, n_attacks_test)
        print("Accuracy:%.2f%%"%(scores[1]*100))
        
        accs.append(scores[1])
        
        y_pred=cldnn.predict(X_test)
        y_label=np.argmax(y_pred,axis=-1)
        cf=confusion_matrix(y_test,y_label)
        
        cfs.append(cf)
# Out:
# Length of y_attack_test 1966
# 578
# XTRAIN_TRAINLEN 2272897 2272897
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape (Reshape)            (None, 31, 80)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 2480)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               317568
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1776/1776 [==============================] - 79s 45ms/step - loss: 0.0797 - accuracy: 0.9710 - val_loss: 0.0222 - val_accuracy: 0.9990
# Epoch 2/20
# 1776/1776 [==============================] - 78s 44ms/step - loss: 0.0394 - accuracy: 0.9876 - val_loss: 0.0140 - val_accuracy: 0.9990
# Epoch 3/20
# 1776/1776 [==============================] - 77s 43ms/step - loss: 0.0173 - accuracy: 0.9952 - val_loss: 0.0071 - val_accuracy: 0.9995
# Epoch 4/20
# 1776/1776 [==============================] - 77s 43ms/step - loss: 0.0095 - accuracy: 0.9978 - val_loss: 0.0103 - val_accuracy: 0.9970
# Epoch 5/20
# 1776/1776 [==============================] - 77s 43ms/step - loss: 0.0129 - accuracy: 0.9966 - val_loss: 0.0034 - val_accuracy: 0.9995
# Epoch 6/20
# 1776/1776 [==============================] - 77s 43ms/step - loss: 0.
20
# 1611/1611 [==============================] - 71s 44ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0073 - val_accuracy: 0.9983
# Epoch 12/20
# 1611/1611 [==============================] - 71s 44ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0036 - val_accuracy: 0.9992
# Epoch 13/20
# 1611/1611 [==============================] - 71s 44ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0158 - val_accuracy: 0.9975
# Epoch 14/20
# 1611/1611 [==============================] - 71s 44ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0055 - val_accuracy: 0.9988
# Epoch 15/20
# 1611/1611 [==============================] - 71s 44ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.0091 - val_accuracy: 0.9981
# Epoch 16/20
# 1611/1611 [==============================] - 71s 44ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0035 - val_accuracy: 0.9990
# Epoch 17/20
# 1611/1611 [==============================] - 71s 44ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0075 - val_accuracy: 0.9985
# Epoch 18/20
# 1611/1611 [==============================] - 71s 44ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0084 - val_accuracy: 0.9982
# Epoch 19/20
# 1611/1611 [==============================] - 71s 44ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0066 - val_accuracy: 0.9988
# Epoch 20/20
# 1611/1611 [==============================] - 71s 44ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0063 - val_accuracy: 0.9979
# 4 1
# 2060841 1136549 924292
# 35579/35579 [==============================] - 64s 2ms/step - loss: 0.3625 - accuracy: 0.9972
# 4 1
# Accuracy:99.72%
# 4 2
# 2060841 1136549 924292
# 39518/39518 [==============================] - 71s 2ms/step - loss: 2.8671 - accuracy: 0.9123
# 4 2
# Accuracy:91.23%
# 4 3
# 2060841 1136549 924292
# 35839/35839 [==============================] - 65s 2ms/step - loss: 0.5764 - accuracy: 0.9901
# 4 3
# Accuracy:99.01%
# 4 4
# 4 5
# 2060841 1136549 924292
# 35689/35689 [==============================] - 64s 2ms/step - loss: 0.5661 - accuracy: 0.9941
# 4 5
# Accuracy:99.41%
# 4 6
# 2060841 1136549 924292
# 35699/35699 [==============================] - 64s 2ms/step - loss: 0.4405 - accuracy: 0.9938
# 4 6
# Accuracy:99.38%
# 4 7
# 2060841 1136549 924292
# 35766/35766 [==============================] - 65s 2ms/step - loss: 0.3095 - accuracy: 0.9920
# 4 7
# Accuracy:99.20%
# 4 10
# 2060841 1136549 924292
# 40484/40484 [==============================] - 73s 2ms/step - loss: 25.4141 - accuracy: 0.8764
# 4 10
# Accuracy:87.64%
# 4 11
# 2060841 1136549 924292
# 35702/35702 [==============================] - 64s 2ms/step - loss: 0.3599 - accuracy: 0.9937
# 4 11
# Accuracy:99.37%
# 4 12
# 2060841 1136549 924292
# 35565/35565 [==============================] - 64s 2ms/step - loss: 0.0275 - accuracy: 0.9976
# 4 12
# Accuracy:99.76%
# 4 14
# 2060841 1136549 924292
# 35538/35538 [==============================] - 64s 2ms/step - loss: 0.0087 - accuracy: 0.9983
# 4 14
# Accuracy:99.83%
# Length of y_attack_test 5499
# 206
# XTRAIN_TRAINLEN 2269343 2269343
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               317568
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1773/1773 [==============================] - 79s 45ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 0.0058 - val_accuracy: 0.9976
# Epoch 2/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.0052 - val_accuracy: 0.9985
# Epoch 3/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0037 - val_accuracy: 0.9991
# Epoch 4/20
# 1773/1773 [==============================] - 79s 44ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0025 - val_accuracy: 0.9991
# Epoch 5/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0039 - val_accuracy: 0.9991
# Epoch 6/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0018 - val_accuracy: 0.9996
# Epoch 7/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0014 - val_accuracy: 0.9996
# Epoch 8/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 8.0687e-04 - val_accuracy: 0.9993
# Epoch 9/20
# 1773/1773 [==============================] - 78s 44ms/step - loss:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               317568
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1776/1776 [==============================] - 79s 45ms/step - loss: 0.0227 - accuracy: 0.9925 - val_loss: 0.0103 - val_accuracy: 0.9964
# Epoch 2/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.0078 - val_accuracy: 0.9976
# Epoch 3/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.0057 - val_accuracy: 0.9974
# Epoch 4/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0065 - val_accuracy: 0.9979
# Epoch 5/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0135 - val_accuracy: 0.9959
# Epoch 6/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0044 - val_accuracy: 0.9985
# Epoch 7/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0050 - val_accuracy: 0.9981
# Epoch 8/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0038 - val_accuracy: 0.9988
# Epoch 9/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0020 - val_accuracy: 0.9991
# Epoch 10/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0032 - val_accuracy: 0.9990
# Epoch 11/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0034 - val_accuracy: 0.9990
# Epoch 12/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0035 - val_accuracy: 0.9990
# Epoch 13/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0030 - val_accuracy: 0.9991
# Epoch 14/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0027 - val_accuracy: 0.9990
# Epoch 15/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0027 - val_accuracy: 0.9991
# Epoch 16/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0021 - val_accuracy: 0.9991
# Epoch 17/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0033 - val_accuracy: 0.9991
# Epoch 18/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0012 - val_accuracy: 0.9991
# Epoch 19/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0016 - val_accuracy: 0.9991
# Epoch 20/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0016 - val_accuracy: 0.9991
# 6 1
# 2272565 1136549 1136016
# 35579/35579 [==============================] - 64s 2ms/step - loss: 0.2057 - accuracy: 0.9982
# 6 1
# Accuracy:99.82%
# 6 2
# 2272565 1136549 1136016
# 39518/39518 [==============================] - 72s 2ms/step - loss: 2.3031 - accuracy: 0.8993
# 6 2
# Accuracy:89.93%
# 6 3
# 2272565 1136549 1136016
# 35839/35839 [==============================] - 65s 2ms/step - loss: 0.0979 - accuracy: 0.9927
# 6 3
# Accuracy:99.27%
# 6 4
# 2272565 1136549 1136016
# 42739/42739 [==============================] - 77s 2ms/step - loss: 1.8860 - accuracy: 0.8781
# 6 4
# Accuracy:87.81%
# 6 5
# 2272565 1136549 1136016
# 35689/35689 [==============================] - 64s 2ms/step - loss: 0.0069 - accuracy: 0.9994
# 6 5
# Accuracy:99.94%
# 6 6
# 6 7
# 2272565 1136549 1136016
# 35766/35766 [==============================] - 65s 2ms/step - loss: 0.0797 - accuracy: 0.9930
# 6 7
# Accuracy:99.30%
# 6 10
# 2272565 1136549 1136016
# 40484/40484 [==============================] - 73s 2ms/step - loss: 14.6590 - accuracy: 0.8772
# 6 10
# Accuracy:87.72%
# 6 11
# 2272565 1136549 1136016
# 35702/35702 [==============================] - 64s 2ms/step - loss: 0.0986 - accuracy: 0.9947
# 6 11
# Accuracy:99.47%
# 6 12
# 2272565 1136549 1136016
# 35565/35565 [==============================] - 64s 2ms/step - loss: 0.0081 - accuracy: 0.9986
# 6 12
# Accuracy:99.86%
# 6 14
# 2272565 1136549 1136016
# 35538/35538 [==============================] - 64s 2ms/step - loss: 0.0029 - accuracy: 0.9993
# 6 14
# Accuracy:99.93%
# Length of y_attack_test 7938
# 143
# XTRAIN_TRAINLEN 2271683 2271683
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout
ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0013 - val_accuracy: 0.9996
# Epoch 15/20
# ...
# Epoch 9/20
# 1773/1773 [==============================] - 79s 44ms/step - loss: 0.0057 - accuracy: 0.9989 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 10/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 9.9497e-04 - val_accuracy: 1.0000
# Epoch 11/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 5.5709e-04 - val_accuracy: 1.0000
# Epoch 12/20
# 1773/1773 [==============================] - 79s 44ms/step - loss: 0.0086 - accuracy: 0.9982 - val_loss: 8.3626e-04 - val_accuracy: 1.0000
# Epoch 13/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0043 - accuracy: 0.9992 - val_loss: 4.4951e-04 - val_accuracy: 1.0000
# Epoch 14/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.0021 - val_accuracy: 0.9998
# Epoch 15/20
# 1773/1773 [==============================] - 79s 44ms/step - loss: 0.0045 - accuracy: 0.9992 - val_loss: 6.2752e-04 - val_accuracy: 1.0000
# Epoch 16/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 17/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 18/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 4.7412e-04 - val_accuracy: 1.0000
# Epoch 19/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 4.8968e-04 - val_accuracy: 1.0000
# Epoch 20/20
# 1773/1773 [==============================] - 78s 44ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 8.2284e-04 - val_accuracy: 1.0000
# 11 1
# 2268773 1136549 1132224
# 35579/35579 [==============================] - 63s 2ms/step - loss: 1.5361 - accuracy: 0.9982
# 11 1
# Accuracy:99.82%
# 11 2
# 2268773 1136549 1132224
# 39518/39518 [==============================] - 70s 2ms/step - loss: 30.8256 - accuracy: 0.8987
# 11 2
# Accuracy:89.87%
# 11 3
# 2268773 1136549 1132224
# 35839/35839 [==============================] - 63s 2ms/step - loss: 1.5820 - accuracy: 0.9910
# 11 3
# Accuracy:99.10%
# 11 4
# 2268773 1136549 1132224
# 42739/42739 [==============================] - 76s 2ms/step - loss: 32.5000 - accuracy: 0.8310
# 11 4
# Accuracy:83.10%
# 11 5
# 2268773 1136549 1132224
# 35689/35689 [==============================] - 63s 2ms/step - loss: 1.2385 - accuracy: 0.9951
# 11 5
# Accuracy:99.51%
# 11 6
# 2268773 1136549 1132224
# 35699/35699 [==============================] - 63s 2ms/step - loss: 0.9092 - accuracy: 0.9954
# 11 6
# Accuracy:99.54%
# 11 7
# 2268773 1136549 1132224
# 35766/35766 [==============================] - 63s 2ms/step - loss: 0.2765 - accuracy: 0.9964
# 11 7
# Accuracy:99.64%
# 11 10
# 2268773 1136549 1132224
# 40484/40484 [==============================] - 71s 2ms/step - loss: 102.7302 - accuracy: 0.8786
# 11 10
# Accuracy:87.86%
# 11 11
# 11 12
# 2268773 1136549 1132224
# 35565/35565 [==============================] - 63s 2ms/step - loss: 0.6272 - accuracy: 0.9986
# 11 12
# Accuracy:99.86%
# 11 14
# 2268773 1136549 1132224
# 35538/35538 [==============================] - 63s 2ms/step - loss: 0.3041 - accuracy: 0.9994
# 11 14
# Accuracy:99.94%
# Length of y_attack_test 1507
# 754
# XTRAIN_TRAINLEN 2272827 2272827
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_9 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               317568
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1776/1776 [==============================] - 79s 45ms/step - loss: 0.0448 - accuracy: 0.9839 - val_loss: 0.0152 - val_accuracy: 0.9980
# Epoch 2/20
# 1776/1776 [==============================] - 79s 44ms/step - loss: 0.0189 - accuracy: 0.9954 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch
# 14 11
# Accuracy:99.32%
# 14 12
# 2272985 1136549 1136436
# 35565/35565 [==============================] - 61s 2ms/step - loss: 0.0094 - accuracy: 0.9982
# 14 12
# Accuracy:99.82%
# 14 14

# %%
# Name of pickle file to be saved
outname = 'conf_matrix_basearch_all_full_balanced.pickle'

outfile = os.path.join(os.getcwd(), outname)
if os.path.exists(outfile):
        os.replace(outfile, outfile + ".old")
        
with open(outfile, 'wb') as file:
    pickle.dump(cfs, file)

# %%
cfs
# Out:
# [array([[1116548,   20000],
#         [ 128027,       0]]),
#  array([[1116548,   20000],
#         [  10293,       0]]),
#  array([[1116548,   20000],
#         [ 231073,       0]]),
#  array([[1116548,   20000],
#         [   5499,       0]]),
#  array([[1116548,   20000],
#         [   5796,       0]]),
#  array([[1116548,   20000],
#         [   7938,       0]]),
#  array([[1116548,   20000],
#         [ 118560,   40370]]),
#  array([[1116548,   20000],
#         [   5897,       0]]),
#  array([[1116548,   20000],
#         [   1507,       0]]),
#  array([[1116548,   20000],
#         [    652,       0]]),
#  array([[1134827,    1721],
#         [   1966,       0]]),
#  array([[1134827,    1721],
#         [   8946,    1347]]),
#  array([[1134827,    1721],
#         [ 230562,     511]]),
#  array([[1134827,    1721],
#         [   5499,       0]]),
#  array([[1134827,    1721],
#         [   5795,       1]]),
#  array([[1134827,    1721],
#         [   7938,       0]]),
#  array([[1134827,    1721],
#         [ 155070,    3860]]),
#  array([[1134827,    1721],
#         [   5897,       0]]),
#  array([[1134827,    1721],
#         [   1507,       0]]),
#  array([[1134827,    1721],
#         [    652,       0]]),
#  array([[1136465,      83],
#         [   1966,       0]]),
#  array([[1136465,      83],
#         [ 110191,   17836]]),
#  array([[1136465,      83],
#         [ 230890,     183]]),
#  array([[1136465,      83],
#         [   5309,     190]]),
#  array([[1136465,      83],
#         [   4091,    1705]]),
#  array([[1136465,      83],
#         [   7938,       0]]),
#  array([[1136465,      83],
#         [ 158902,      28]]),
#  array([[1136465,      83],
#         [   5889,       8]]),
#  array([[1136465,      83],
#         [   1507,       0]]),
#  array([[1136465,      83],
#         [    649,       3]]),
#  array([[1135286,    1262],
#         [   1966,       0]]),
#  array([[1135286,    1262],
#         [ 109627,   18400]]),
#  array([[1135286,    1262],
#         [  10147,     146]]),
#  array([[1135286,    1262],
#         [   5499,       0]]),
#  array([[1135286,    1262],
#         [   5794,       2]]),
#  array([[1135286,    1262],
#         [   7938,       0]]),
#  array([[1135286,    1262],
#         [ 158819,     111]]),
#  array([[1135286,    1262],
#         [   5896,       1]]),
#  array([[1135286,    1262],
#         [   1507,       0]]),
#  array([[1135286,    1262],
#         [    652,       0]]),
#  array([[1136410,     138],
#         [   1966,       0]]),
#  array([[1136410,     138],
#         [ 128027,       0]]),
#  array([[1136410,     138],
#         [   6891,    3402]]),
#  array([[1136410,     138],
#         [ 231058,      15]]),
#  array([[1136410,     138],
#         [   1707,    4089]]),
#  array([[1136410,     138],
#         [   7938,       0]]),
#  array([[1136410,     138],
#         [ 158920,      10]]),
#  array([[1136410,     138],
#         [   5897,       0]]),
#  array([[1136410,     138],
#         [   1230,     277]]),
#  array([[1136410,     138],
#         [    539,     113]]),
#  array([[1136424,     124],
#         [   1966,       0]]),
#  array([[1136424,     124],
#         [ 127235,     792]]),
#  array([[1136424,     124],
#         [   8222,    2071]]),
#  array([[1136424,     124],
#         [ 166554,   64519]]),
#  array([[1136424,     124],
#         [    518,    4981]]),
#  array([[1136424,     124],
#         [   7895,      43]]),
#  array([[1136424,     124],
#         [ 158926,       4]]),
#  array([[1136424,     124],
#         [   5895,       2]]),
#  array([[1136424,     124],
#         [   1432,      75]]),
#  array([[1136424,     124],
#         [    642,      10]]),
#  array([[1136509,      39],
#         [   1966,       0]]),
#  array([[1136509,      39],
#         [ 128027,       0]]),
#  array([[1136509,      39],
#         [  10293,       0]]),
#  array([[1136509,      39],
#         [ 231073,       0]]),
#  array([[1136509,      39],
#         [   5247,     252]]),
#  array([[1136509,      39],
#         [   5274,     522]]),
#  array([[1136509,      39],
#         [ 158930,       0]]),
#  array([[1136509,      39],
#         [   5882,      15]]),
#  array([[1136509,      39],
#         [   1507,       0]]),
#  array([[1136509,      39],
#         [    652,       0]]),
#  array([[1073372,   63176],
#         [   1966,       0]]),
#  array([[1073372,   63176],
#         [ 124701,    3326]]),
#  array([[1073372,   63176],
#         [   8790,    1503]]),
#  array([[1073372,   63176],
#         [ 230322,     751]]),
#  array([[1073372,   63176],
#         [   5499,       0]]),
#  array([[1073372,   63176],
#         [   5796,       0]]),
#  array([[1073372,   63176],
#         [   5662,    2276]]),
#  array([[1073372,   63176],
#         [   5897,       0]]),
#  array([[1073372,   63176],
#         [   1505,       2]]),
#  array([[1073372,   63176],
#         [    651,       1]]),
#  array([[1136490,      58],
#         [   1966,       0]]),
#  array([[1136490,      58],
#         [ 128027,       0]]),
#  array([[1136490,      58],
#         [  10293,       0]]),
#  array([[1136490,      58],
#         [ 231073,       0]]),
#  array([[1136490,      58],
#         [   5481,      18]]),
#  array([[1136490,      58],
#         [   5204,     592]]),
#  array([[1136490,      58],
#         [   4072,    3866]]),
#  array([[1136490,      58],
#         [ 157165,    1765]]),
#  array([[1136490,      58],
#         [   1507,       0]]),
#  array([[1136490,      58],
#         [    652,       0]]),
#  array([[1136357,     191],
#         [   1966,       0]]),
#  array([[1136357,     191],
#         [ 128027,       0]]),
#  array([[1136357,     191],
#         [   9779,     514]]),
#  array([[1136357,     191],
#         [ 230085,     988]]),
#  array([[1136357,     191],
#         [   5495,       4]]),
#  array([[1136357,     191],
#         [   5792,       4]]),
#  array([[1136357,     191],
#         [   7937,       1]]),
#  array([[1136357,     191],
#         [ 158918,      12]]),
#  array([[1136357,     191],
#         [   5897,       0]]),
#  array([[1136357,     191],
#         [     41,     611]]),
#  array([[1134630,    1918],
#         [   1966,       0]]),
#  array([[1134630,    1918],
#         [ 128026,       1]]),
#  array([[1134630,    1918],
#         [   9152,    1141]]),
#  array([[1134630,    1918],
#         [ 231031,      42]]),
#  array([[1134630,    1918],
#         [   5493,       6]]),
#  array([[1134630,    1918],
#         [   5788,       8]]),
#  array([[1134630,    1918],
#         [   7937,       1]]),
#  array([[1134630,    1918],
#         [ 158912,      18]]),
#  array([[1134630,    1918],
#         [   5888,       9]]),
#  array([[1134630,    1918],
#         [    151,    1356]])]

# %%
with open('conf_matrix_basearch_all_full_balanced.pickle', 'rb') as file:
    cfs = pickle.load(file)

# %%
len(cfs)
# Out:
# 110

# %%
accuracy = []
attack_accuracy = []

for i in range(len(cfs)):
    accuracy.append(np.round(np.trace(cfs[i])/np.sum(cfs[i])*100,2))
    attack_accuracy.append(np.nan_to_num(np.round(cfs[i][1][1]/(cfs[i][0][1]+cfs[i][1][1])*100,2)))

# %%
attacks = [1,2,3,4,5,6,7,10,11,12,14]# Attacks that are retained
# Convert from 1D to 2D
numattacks = len(attacks)
accr = np.zeros((numattacks, numattacks))
attackaccr = np.zeros((numattacks, numattacks))

n = 0

for i in range(numattacks):
    for j in range(numattacks):
        if i == j:
            accr[i][j] = 100
            continue
        else:
            accr[i][j] = accuracy[n]
            attackaccr[i][j] = attack_accuracy[n]
            n = n + 1

# %%
# Create Datafeame and update row/column names
accrd = pd.DataFrame(accr)
ataccrd = pd.DataFrame(attackaccr)

#accrd.columns=accrmat.columns.values
accrd.columns=y_attacks
accrd.index=y_attacks
ataccrd.columns=y_attacks
ataccrd.index=y_attacks

# %%
fig = plt.figure(figsize=(10, 8), dpi=150)

plt.rcParams["font.family"] = "serif"
plt.rc('axes', titlesize=12)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=11)    # legend fontsize
plt.rc('axes', titlesize=15)  # fontsize of the figure title
# create some labels
attack_labels = [ "{0:d}".format(i) for i in attacks ]

# create a color map with random colors
#colmap = matplotlib.colors.ListedColormap(np.random.random((21,3)))
#colmap.colors[0] = [0,0,0]
import seaborn as sns
# this is the real plotting part
ax = fig.add_subplot(111)
sns.heatmap(accrd, linewidths=.5, annot=True, fmt='.2f', cmap='winter', ax=ax)


plt.xlabel('Test Attack')
plt.ylabel('Training Attack')
plt.title('Overall accuracy when training and testing with individual attacks')

plt.show()

# %%
fig = plt.figure(figsize=(10, 8), dpi=150)

plt.rcParams["font.family"] = "serif"
plt.rc('axes', titlesize=12)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=11)    # legend fontsize
plt.rc('axes', titlesize=15)  # fontsize of the figure title
# create some labels
attack_labels = [ "{0:d}".format(i) for i in attacks ]

# create a color map with random colors
#colmap = matplotlib.colors.ListedColormap(np.random.random((21,3)))
#colmap.colors[0] = [0,0,0]

# this is the real plotting part
ax = fig.add_subplot(111)
sns.heatmap(ataccrd, linewidths=.5, annot=True, fmt='.2f', cmap='winter', ax=ax)


plt.xlabel('Test Attack')
plt.ylabel('Training Attack')
plt.title('Attack Accuracy when training and testing with individual attacks (Second Run)')

plt.show()
