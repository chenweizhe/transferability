# %%
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Reshape, LSTM, LeakyReLU
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.metrics import confusion_matrix
from scipy.stats import multivariate_normal
import math
import os
import random
import pickle
import tensorflow as tf
#which gpu is available?
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
path='results/cicids/all_features/differential_input/'

if not os.path.exists(path):
    os.makedirs(path)

# %%
#block to get reproducible results
seed_value=1
os.environ['PYTHONHASHSEED']=str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
#import dataset
dataset=pd.read_csv('../../MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv')
dataset_1=pd.read_csv('../../MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv')
dataset_2=pd.read_csv('../../MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')
dataset_3=pd.read_csv('../../MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')
dataset_4=pd.read_csv('../../MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')
dataset_5=pd.read_csv('../../MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')
dataset_6=pd.read_csv('../../MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv')
dataset_7=pd.read_csv('../../MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv')

# %%
dataset=dataset.append(dataset_1, ignore_index=True)
dataset=dataset.append(dataset_2, ignore_index=True)
dataset=dataset.append(dataset_3, ignore_index=True)
dataset=dataset.append(dataset_4, ignore_index=True)
dataset=dataset.append(dataset_5, ignore_index=True)
dataset=dataset.append(dataset_6, ignore_index=True)
dataset=dataset.append(dataset_7, ignore_index=True)

# %%
dataset.head()
dataset[dataset==np.inf]=np.nan
dataset.fillna(0,inplace=True)
x_dataset=dataset.iloc[:, :-1]
y=dataset.iloc[:, -1]

# %%
le=LabelEncoder()
y_encoded=le.fit_transform(y)
# le.classes_

# %%
scaler=MinMaxScaler()
x_dataset_scaled=scaler.fit_transform(x_dataset)

# %%
def to_onehot(yy):
    yy1 = np.zeros([len(yy), max(yy)+1])
    yy1[np.arange(len(yy)),yy] = 1
    return yy1

# %%
#FIND OUT INDICES OF Y AND X THAT ARE ONLY NORMAL AND DIVIDE intow two parts
y_normal_indices=np.where(y_encoded==0)
y_normal_indices_list=np.array_split(y_normal_indices[0],2)
y_normal_train=y_encoded[y_normal_indices_list[0]]
y_normal_test=y_encoded[y_normal_indices_list[1]]
x_normal_train=x_dataset_scaled[y_normal_indices_list[0]]
x_normal_test=x_dataset_scaled[y_normal_indices_list[1]]
print(len(y_normal_train), len(y_normal_test), len(x_normal_train), len(x_normal_test))
# Out:
# 1136549 1136548 1136549 1136548

# %%
y_val,y_count = np.unique(y_encoded, return_counts=True) 
y_retained = y_val[y_count>100]
y_attacks = y_retained[y_retained>0]

accs = []
cfs = []
cfs_diff=[]
y_attacks
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7, 10, 11, 12, 14])

# %%
for n_attacks_train in y_attacks:
    #find the training attacks
    y_train_indices=np.where(y_encoded==n_attacks_train)

    y_attack_train=np.ones(len(y_train_indices[0]),dtype=int)  
    #find the x_dataset corr to this
    x_attack_train=x_dataset_scaled[y_train_indices[0]]
    
    
    #create the training data
    x_train=np.concatenate([x_attack_train,x_normal_train])
    y_train=np.concatenate([y_attack_train,y_normal_train])
    
    print("Length of y_attack_test",len(y_attack_train))
    n=(int)(len(y_normal_train)/len(y_attack_train))
    print(n)
    
    #bootstrap here
    for i in range(n-1):
        x_train=np.concatenate([x_train,x_attack_train])
        y_train=np.concatenate([y_train,y_attack_train])
        
    print("XTRAIN_TRAINLEN", len(x_train),len(y_train))
    
    #differential inputs here
    
    x_diff=np.zeros(x_train.shape)
    for i in range(len(x_train)):
        if i!=0:
            x_diff[i,:]=x_train[i,:]-x_train[i-1,:]
            #x_diff=pd.concat([x_diff,(x_train.iloc[i,:]-x_train.iloc[i-1,:]).to_frame().T], ignore_index=True)
        else: 
            #x_diff=pd.concat([x_diff, x_train[i,:].to_frame().T],ignore_index=True)
            x_diff[i,:]=x_train[i,:]
            
    # Need to declare it every time, otherwise it gets erased from memory
    def cldnn():
          #FILL THIS IN WITH MODEL ARCHITECTURE
        model = Sequential()
        model.add(Conv2D(256,(1,3),activation="relu",input_shape =(2,39,1)))
        model.add(Conv2D(256,(2,3),activation=None))
        model.add(LeakyReLU(0.3))
        model.add(Conv2D(256,(1,3),activation=None))
        model.add(LeakyReLU(0.3))
        model.add(Dropout(0.20))
        model.add(Conv2D(80,(1,3),activation="relu"))
        model.add(Reshape((31,80)))
        model.add(Flatten())
        model.add(Dense(128,activation="relu",kernel_initializer="normal"))
        model.add(Dense(2,activation="sigmoid"))
        model.summary()
        return model
        
    cldnn = cldnn()
    cldnn.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
    
    x_train_examples,_=x_diff.shape
    Y_train = to_onehot(y_train)
    X_train = x_diff.reshape(x_train_examples, 2, 39, 1)
        
    cldnn_mdata=cldnn.fit(X_train,Y_train,validation_split=0.2,epochs=20,batch_size =1024,shuffle=True)
    
    if not os.path.exists(path+f'weights/{n_attacks_train}'):
        os.makedirs(path+f'weights/{n_attacks_train}')
    
    cldnn.save(path+f'weights/{n_attacks_train}/weights.h5')
    
    for n_attacks_test in y_attacks:
        print(n_attacks_train, n_attacks_test)

        #find the testing attacks
        if n_attacks_test== n_attacks_train:
            continue
        else:
            y_test_indices=np.where(y_encoded==n_attacks_test)
            y_test_indices=y_test_indices[0] 
        
        y_attack_test=np.ones(len(y_test_indices),dtype=int)
        
        print(len(x_train),len(y_train[y_train==0]),len(y_train[y_train==1]))
            
        #find the x_dataset corr to this
        x_attack_test=x_dataset_scaled[y_test_indices]

        #create the testing data
        x_test=np.concatenate([x_attack_test,x_normal_test])
        y_test=np.concatenate([y_attack_test,y_normal_test])   
    
        #print("TRAINING", len(y_train),len(y_train[y_train==0]), len(y_train[y_train==1]))
        #print("TESTING", len(y_test),len(y_test[y_test==0]), len(y_test[y_test==1]))   
        
        
        x_test_examples,_= x_test.shape
                
        
        Y_test = to_onehot(y_test)
        X_test = x_test.reshape(x_test_examples, 2, 39, 1)

        scores=cldnn.evaluate(X_test,Y_test)
        
        print(n_attacks_train, n_attacks_test)
        print("Accuracy:%.2f%%"%(scores[1]*100))
        
        accs.append(scores[1])
        
        y_pred=cldnn.predict(X_test)
        y_label=np.argmax(y_pred,axis=-1)
        cf=confusion_matrix(y_test,y_label)
        
        cfs.append(cf)
        
        #test the differential inputs here
        x_diff_test=np.zeros(x_test.shape)
        
        for i in range(len(x_test)):
            if i!=0:
                x_diff_test[i,:]=x_test[i,:]-x_test[i-1,:]
                #x_diff=pd.concat([x_diff,(x_train.iloc[i,:]-x_train.iloc[i-1,:]).to_frame().T], ignore_index=True)
            else: 
                #x_diff=pd.concat([x_diff, x_train[i,:].to_frame().T],ignore_index=True)
                x_diff_test[i,:]=x_test[i,:]
        
        x_test_examples,_= x_diff_test.shape
        X_test = x_diff_test.reshape(x_test_examples, 2, 39, 1)

        y_pred=cldnn.predict(X_test)
        y_label=np.argmax(y_pred,axis=-1)
        cf=confusion_matrix(y_test,y_label)
        
        cfs_diff.append(cf)
# Out:
# Length of y_attack_test 1966
# 578
# XTRAIN_TRAINLEN 2272897 2272897
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape (Reshape)            (None, 31, 80)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 2480)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               317568
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1776/1776 [==============================] - 77s 43ms/step - loss: 0.1629 - accuracy: 0.9266 - val_loss: 0.0596 - val_accuracy: 0.9985
# Epoch 2/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0677 - accuracy: 0.9749 - val_loss: 0.0399 - val_accuracy: 0.9970
# Epoch 3/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0489 - accuracy: 0.9798 - val_loss: 0.0324 - val_accuracy: 0.9959
# Epoch 4/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0394 - accuracy: 0.9829 - val_loss: 0.0258 - val_accuracy: 0.9970
# Epoch 5/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0315 - accuracy: 0.9859 - val_loss: 0.0134 - val_accuracy: 0.9990
# Epoch 6/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0221 - accuracy: 0.9914 - val_loss: 0.0120 - val_accuracy: 0.9939
# Epoch 7/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 0.0297 - val_accuracy: 0.9888
# Epoch 8/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0202 - accuracy: 0.9923 - val_loss: 0.0145 - val_accuracy: 0.9929
# Epoch 9/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0145 - accuracy: 0.9951 - val_loss: 0.0119 - val_accuracy: 0.9949
# Epoch 10/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.0052 - val_accuracy: 0.9980
# Epoch 11/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.0094 - val_accuracy: 0.9959
# Epoch 12/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0084 - accuracy: 0.9976 - val_loss: 0.0048 - val_accuracy: 0.9990
# Epoch 13/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.0061 - val_accuracy: 0.9980
# Epoch 14/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.0079 - val_accuracy: 0.9964
# Epoch 15/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 16/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0072 - val_accuracy: 0.9975
# Epoch 17/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.0029 - val_accuracy: 0.9995
# Epoch 18/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0054 - val_accuracy: 0.9980
# Epoch 19/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.0017 - val_accuracy: 0.9995
# Epoch 20/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.0017 - val_accuracy: 1.0000
# 1 1
# 1 2
# 2272897 1136549 1136348
# 39518/39518 [==============================] - 94s 2ms/step - loss: 36.6306 - accuracy: 0.8819
# 1 2
# Accuracy:88.19%
# 1 3
# 2272897 1136549 1136348
# 35839/35839 [==============================] - 85s 2ms/step - loss: 1.3494 - accuracy: 0.9725
# 1 3
# Accuracy:97.25%
# 1 4
# 2272897 1136549 1136348
# 42739/42739 [==============================] - 102s 2ms/step - loss: 95.0212 - accuracy: 0.8155
# 1 4
# Accuracy:81.55%
# 1 5
# 2272897 1136549 1136348
# 35689/35689 [==============================] - 82s 2ms/step - loss: 1.0043 - accuracy: 0.9790
# 1 5
# Accuracy:97.90%
# 1 6
# 2272897 1136549 1136348
# 35699/35699 [==============================] - 84s 2ms/step - loss: 0.9299 - accuracy: 0.9764
# 1 6
# Accuracy:97.64%
# 1 7
# 2272897 1136549 1136348
# 35766/35766 [==============================] - 85s 2ms/step - loss: 2.5436 - accuracy: 0.9754
# 1 7
# Accuracy:97.54%
# 1 10
# 2272897 1136549 1136348
# 40484/40484 [==============================] - 96s 2ms/step - loss: 14.4144 - accuracy: 0.8610
# 1 10
# Accuracy:86.10%
# 1 11
# 2272897 1136549 1136348
# 35702/35702 [==============================] - 80s 2ms/step - loss: 1.2532 - accuracy: 0.9763
# 1 11
# Accuracy:97.63%
# 1 12
# 2272897 1136549 1136348
# 35565/35565 [==============================] - 83s 2ms/step - loss: 0.4088 - accuracy: 0.9800
# 1 12
# Accuracy:98.00%
# 1 14
# 2272897 1136549 1136348
# 35538/35538 [==============================] - 85s 2ms/step - loss: 0.3520 - accuracy: 0.9807
# 1 14
# Accuracy:98.07%
# Length of y_attack_test 128027
# 8
# XTRAIN_TRAINLEN 2160765 2160765
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               317568
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1689/1689 [==============================] - 72s 42ms/step - loss: 0.1210 - accuracy: 0.9459 - val_loss: 0.0365 - val_accuracy: 0.9986
# Epoch 2/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0430 - accuracy: 0.9783 - val_loss: 0.0572 - val_accuracy: 0.9964
# Epoch 3/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0379 - accuracy: 0.9818 - val_loss: 0.0563 - val_accuracy: 0.9977
# Epoch 4/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0354 - accuracy: 0.9833 - val_loss: 0.0446 - val_accuracy: 0.9971
# Epoch 5/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0323 - accuracy: 0.9854 - val_loss: 0.0458 - val_accuracy: 0.9964
# Epoch 6/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0283 - accuracy: 0.9880 - val_loss: 0.0207 - val_accuracy: 0.9986
# Epoch 7/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0243 - accuracy: 0.9896 - val_loss: 0.0347 - val_accuracy: 0.9981
# Epoch 8/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0231 - accuracy: 0.9901 - val_loss: 0.0260 - val_accuracy: 0.9993
# Epoch 9/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0205 - accuracy: 0.9911 - val_loss: 0.0109 - val_accuracy: 0.9990
# Epoch 10/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0182 - accuracy: 0.9918 - val_loss: 0.0141 - val_accuracy: 0.9988
# Epoch 11/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0174 - accuracy: 0.9922 - val_loss: 0.0152 - val_accuracy: 0.9988
# Epoch 12/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0173 - accuracy: 0.9923 - val_loss: 0.0148 - val_accuracy: 0.9987
# Epoch 13/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0154 - accuracy: 0.9930 - val_loss: 0.0291 - val_accuracy: 0.9987
# Epoch 14/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0174 - accuracy: 0.9924 - val_loss: 0.0159 - val_accuracy: 0.9985
# Epoch 15/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0152 - accuracy: 0.9930 - val_loss: 0.0123 - val_accuracy: 0.9990
# Epoch 16/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0182 - accuracy: 0.9912 - val_loss: 0.0124 - val_accuracy: 0.9992
# Epoch 17/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0151 - accuracy: 0.9931 - val_loss: 0.0121 - val_accuracy: 0.9990
# Epoch 18/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0136 - accuracy: 0.9935 - val_loss: 0.0125 - val_accuracy: 0.9986
# Epoch 19/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0134 - accuracy: 0.9937 - val_loss: 0.0152 - val_accuracy: 0.9990
# Epoch 20/20
# 1689/1689 [==============================] - 71s 42ms/step - loss: 0.0134 - accuracy: 0.9935 - val_loss: 0.0145 - val_accuracy: 0.9981
# 2 1
# 2160765 1136549 1024216
# 35579/35579 [==============================] - 85s 2ms/step - loss: 0.3451 - accuracy: 0.9958
# 2 1
# Accuracy:99.58%
# 2 2
# 2 3
# 2160765 1136549 1024216
# 35839/35839 [==============================] - 85s 2ms/step - loss: 0.6021 - accuracy: 0.9928
# 2 3
# Accuracy:99.28%
# 2 4
# 2160765 1136549 1024216
# 42739/42739 [==============================] - 100s 2ms/step - loss: 35.5232 - accuracy: 0.8394
# 2 4
# Accuracy:83.94%
# 2 5
# 2160765 1136549 1024216
# 35689/35689 [==============================] - 83s 2ms/step - loss: 2.8620 - accuracy: 0.9927
# 2 5
# Accuracy:99.27%
# 2 6
# 2160765 1136549 1024216
# 35699/35699 [==============================] - 82s 2ms/step - loss: 4.9224 - accuracy: 0.9925
# 2 6
# Accuracy:99.25%
# 2 7
# 2160765 1136549 1024216
# 35766/35766 [==============================] - 85s 2ms/step - loss: 1.5353 - accuracy: 0.9906
# 2 7
# Accuracy:99.06%
# 2 10
# 2160765 1136549 1024216
# 40484/40484 [==============================] - 94s 2ms/step - loss: 18.7881 - accuracy: 0.8752
# 2 10
# Accuracy:87.52%
# 2 11
# 2160765 1136549 1024216
# 35702/35702 [==============================] - 85s 2ms/step - loss: 0.8743 - accuracy: 0.9924
# 2 11
# Accuracy:99.24%
# 2 12
# 2160765 1136549 1024216
# 35565/35565 [==============================] - 83s 2ms/step - loss: 0.3932 - accuracy: 0.9962
# 2 12
# Accuracy:99.62%
# 2 14
# 2160765 1136549 1024216
# 35538/35538 [==============================] - 81s 2ms/step - loss: 0.1963 - accuracy: 0.9970
# 2 14
# Accuracy:99.70%
# Length of y_attack_test 10293
# 110
# XTRAIN_TRAINLEN 2268779 2268779
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               317568
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1773/1773 [==============================] - 76s 43ms/step - loss: 0.1359 - accuracy: 0.9343 - val_loss: 0.0524 - val_accuracy: 0.9550
# Epoch 2/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0382 - accuracy: 0.9797 - val_loss: 0.0372 - val_accuracy: 0.9963
# Epoch 3/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0323 - accuracy: 0.9818 - val_loss: 0.0311 - val_accuracy: 0.9984
# Epoch 4/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0320 - accuracy: 0.9825 - val_loss: 0.0336 - val_accuracy: 0.9968
# Epoch 5/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0290 - accuracy: 0.9844 - val_loss: 0.0249 - val_accuracy: 0.9986
# Epoch 6/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0274 - accuracy: 0.9854 - val_loss: 0.0343 - val_accuracy: 0.9962
# Epoch 7/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0268 - accuracy: 0.9861 - val_loss: 0.0461 - val_accuracy: 0.9553
# Epoch 8/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0257 - accuracy: 0.9870 - val_loss: 0.0285 - val_accuracy: 0.9978
# Epoch 9/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0243 - accuracy: 0.9881 - val_loss: 0.0221 - val_accuracy: 0.9997
# Epoch 10/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0238 - accuracy: 0.9883 - val_loss: 0.0175 - val_accuracy: 0.9996
# Epoch 11/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0222 - accuracy: 0.9892 - val_loss: 0.0195 - val_accuracy: 0.9972
# Epoch 12/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0216 - accuracy: 0.9894 - val_loss: 0.0213 - val_accuracy: 0.9979
# Epoch 13/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0213 - accuracy: 0.9897 - val_loss: 0.0255 - val_accuracy: 0.9936
# Epoch 14/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0193 - accuracy: 0.9907 - val_loss: 0.0147 - val_accuracy: 0.9956
# Epoch 15/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0157 - accuracy: 0.9932 - val_loss: 0.0109 - val_accuracy: 0.9988
# Epoch 16/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0129 - accuracy: 0.9941 - val_loss: 0.0141 - val_accuracy: 0.9915
# Epoch 17/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0131 - accuracy: 0.9940 - val_loss: 0.0106 - val_accuracy: 0.9931
# Epoch 18/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0116 - accuracy: 0.9950 - val_loss: 0.0166 - val_accuracy: 0.9917
# Epoch 19/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0122 - accuracy: 0.9947 - val_loss: 0.0097 - val_accuracy: 0.9937
# Epoch 20/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0109 - accuracy: 0.9952 - val_loss: 0.0101 - val_accuracy: 0.9935
# 3 1
# 2268779 1136549 1132230
# 35579/35579 [==============================] - 84s 2ms/step - loss: 1.0634 - accuracy: 0.9767
# 3 1
# Accuracy:97.67%
# 3 2
# 2268779 1136549 1132230
# 39518/39518 [==============================] - 91s 2ms/step - loss: 0.7476 - accuracy: 0.9525
# 3 2
# Accuracy:95.25%
# 3 3
# 3 4
# 2268779 1136549 1132230
# 42739/42739 [==============================] - 99s 2ms/step - loss: 18.2484 - accuracy: 0.8332
# 3 4
# Accuracy:83.32%
# 3 5
# 2268779 1136549 1132230
# 35689/35689 [==============================] - 83s 2ms/step - loss: 1.4763 - accuracy: 0.9737
# 3 5
# Accuracy:97.37%
# 3 6
# 2268779 1136549 1132230
# 35699/35699 [==============================] - 84s 2ms/step - loss: 2.1447 - accuracy: 0.9735
# 3 6
# Accuracy:97.35%
# 3 7
# 2268779 1136549 1132230
# 35766/35766 [==============================] - 82s 2ms/step - loss: 4.2777 - accuracy: 0.9716
# 3 7
# Accuracy:97.16%
# 3 10
# 2268779 1136549 1132230
# 40484/40484 [==============================] - 96s 2ms/step - loss: 12.2387 - accuracy: 0.8584
# 3 10
# Accuracy:85.84%
# 3 11
# 2268779 1136549 1132230
# 35702/35702 [==============================] - 85s 2ms/step - loss: 0.7092 - accuracy: 0.9734
# 3 11
# Accuracy:97.34%
# 3 12
# 2268779 1136549 1132230
# 35565/35565 [==============================] - 84s 2ms/step - loss: 0.9422 - accuracy: 0.9771
# 3 12
# Accuracy:97.71%
# 3 14
# 2268779 1136549 1132230
# 35538/35538 [==============================] - 85s 2ms/step - loss: 0.7348 - accuracy: 0.9778
# 3 14
# Accuracy:97.78%
# Length of y_attack_test 231073
# 4
# XTRAIN_TRAINLEN 2060841 2060841
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               317568
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1611/1611 [==============================] - 69s 42ms/step - loss: 0.1344 - accuracy: 0.9360 - val_loss: 0.0839 - val_accuracy: 0.9943
# Epoch 2/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0537 - accuracy: 0.9710 - val_loss: 0.1120 - val_accuracy: 0.8992
# Epoch 3/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0466 - accuracy: 0.9747 - val_loss: 0.1253 - val_accuracy: 0.9066
# Epoch 4/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0426 - accuracy: 0.9776 - val_loss: 0.1075 - val_accuracy: 0.9371
# Epoch 5/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0379 - accuracy: 0.9804 - val_loss: 0.0375 - val_accuracy: 0.9977
# Epoch 6/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0333 - accuracy: 0.9827 - val_loss: 0.0385 - val_accuracy: 0.9944
# Epoch 7/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0321 - accuracy: 0.9831 - val_loss: 0.0528 - val_accuracy: 0.9534
# Epoch 8/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0307 - accuracy: 0.9839 - val_loss: 0.0357 - val_accuracy: 0.9957
# Epoch 9/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0299 - accuracy: 0.9843 - val_loss: 0.0401 - val_accuracy: 0.9953
# Epoch 10/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0300 - accuracy: 0.9847 - val_loss: 0.0575 - val_accuracy: 0.9515
# Epoch 11/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0289 - accuracy: 0.9853 - val_loss: 0.0418 - val_accuracy: 0.9944
# Epoch 12/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0289 - accuracy: 0.9857 - val_loss: 0.0382 - val_accuracy: 0.9917
# Epoch 13/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0269 - accuracy: 0.9869 - val_loss: 0.0353 - val_accuracy: 0.9955
# Epoch 14/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0266 - accuracy: 0.9874 - val_loss: 0.0326 - val_accuracy: 0.9966
# Epoch 15/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0256 - accuracy: 0.9880 - val_loss: 0.0322 - val_accuracy: 0.9954
# Epoch 16/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0247 - accuracy: 0.9886 - val_loss: 0.0245 - val_accuracy: 0.9978
# Epoch 17/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0251 - accuracy: 0.9888 - val_loss: 0.0284 - val_accuracy: 0.9963
# Epoch 18/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0235 - accuracy: 0.9893 - val_loss: 0.0271 - val_accuracy: 0.9964
# Epoch 19/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0229 - accuracy: 0.9899 - val_loss: 0.0257 - val_accuracy: 0.9971
# Epoch 20/20
# 1611/1611 [==============================] - 68s 42ms/step - loss: 0.0225 - accuracy: 0.9901 - val_loss: 0.0396 - val_accuracy: 0.9965
# 4 1
# 2060841 1136549 924292
# 35579/35579 [==============================] - 80s 2ms/step - loss: 0.4223 - accuracy: 0.9983
# 4 1
# Accuracy:99.83%
# 4 2
# 2060841 1136549 924292
# 39518/39518 [==============================] - 89s 2ms/step - loss: 17.1077 - accuracy: 0.8988
# 4 2
# Accuracy:89.88%
# 4 3
# 2060841 1136549 924292
# 35839/35839 [==============================] - 81s 2ms/step - loss: 1.2761 - accuracy: 0.9910
# 4 3
# Accuracy:99.10%
# 4 4
# 4 5
# 2060841 1136549 924292
# 35689/35689 [==============================] - 86s 2ms/step - loss: 1.2830 - accuracy: 0.9952
# 4 5
# Accuracy:99.52%
# 4 6
# 2060841 1136549 924292
# 35699/35699 [==============================] - 82s 2ms/step - loss: 1.4972 - accuracy: 0.9949
# 4 6
# Accuracy:99.49%
# 4 7
# 2060841 1136549 924292
# 35766/35766 [==============================] - 83s 2ms/step - loss: 2.1480 - accuracy: 0.9931
# 4 7
# Accuracy:99.31%
# 4 10
# 2060841 1136549 924292
# 40484/40484 [==============================] - 92s 2ms/step - loss: 26.9344 - accuracy: 0.8773
# 4 10
# Accuracy:87.73%
# 4 11
# 2060841 1136549 924292
# 35702/35702 [==============================] - 82s 2ms/step - loss: 0.8997 - accuracy: 0.9948
# 4 11
# Accuracy:99.48%
# 4 12
# 2060841 1136549 924292
# 35565/35565 [==============================] - 81s 2ms/step - loss: 0.2525 - accuracy: 0.9987
# 4 12
# Accuracy:99.87%
# 4 14
# 2060841 1136549 924292
# 35538/35538 [==============================] - 81s 2ms/step - loss: 0.1119 - accuracy: 0.9994
# 4 14
# Accuracy:99.94%
# Length of y_attack_test 5499
# 206
# XTRAIN_TRAINLEN 2269343 2269343
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               317568
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1773/1773 [==============================] - 76s 42ms/step - loss: 0.1735 - accuracy: 0.9266 - val_loss: 0.0724 - val_accuracy: 0.9971
# Epoch 2/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0743 - accuracy: 0.9794 - val_loss: 0.0529 - val_accuracy: 0.9995
# Epoch 3/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0604 - accuracy: 0.9833 - val_loss: 0.0388 - val_accuracy: 0.9982
# Epoch 4/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0496 - accuracy: 0.9861 - val_loss: 0.0286 - val_accuracy: 0.9980
# Epoch 5/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0416 - accuracy: 0.9884 - val_loss: 0.0162 - val_accuracy: 0.9989
# Epoch 6/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0280 - accuracy: 0.9915 - val_loss: 0.0083 - val_accuracy: 0.9991
# Epoch 7/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0212 - accuracy: 0.9929 - val_loss: 0.0279 - val_accuracy: 0.9980
# Epoch 8/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0185 - accuracy: 0.9935 - val_loss: 0.0112 - val_accuracy: 0.9991
# Epoch 9/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0165 - accuracy: 0.9942 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 10/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0163 - accuracy: 0.9940 - val_loss: 0.0078 - val_accuracy: 0.9995
# Epoch 11/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0153 - accuracy: 0.9943 - val_loss: 0.0130 - val_accuracy: 0.9998
# Epoch 12/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0144 - accuracy: 0.9946 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 13/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0128 - accuracy: 0.9951 - val_loss: 0.0091 - val_accuracy: 0.9996
# Epoch 14/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0127 - accuracy: 0.9950 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 15/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0122 - accuracy: 0.9952 - val_loss: 0.0076 - val_accuracy: 0.9998
# Epoch 16/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0123 - accuracy: 0.9952 - val_loss: 0.0110 - val_accuracy: 0.9996
# Epoch 17/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0110 - accuracy: 0.9954 - val_loss: 0.0094 - val_accuracy: 0.9998
# Epoch 18/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0110 - accuracy: 0.9955 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 19/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0410 - accuracy: 0.9880 - val_loss: 0.0223 - val_accuracy: 0.9980
# Epoch 20/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0340 - accuracy: 0.9893 - val_loss: 0.0158 - val_accuracy: 0.9998
# 5 1
# 2269343 1136549 1132794
# 35579/35579 [==============================] - 79s 2ms/step - loss: 105.4027 - accuracy: 0.8779
# 5 1
# Accuracy:87.79%
# 5 2
# 2269343 1136549 1132794
# 39518/39518 [==============================] - 89s 2ms/step - loss: 124.2604 - accuracy: 0.8378
# 5 2
# Accuracy:83.78%
# 5 3
# 2269343 1136549 1132794
# 35839/35839 [==============================] - 81s 2ms/step - loss: 105.2674 - accuracy: 0.8779
# 5 3
# Accuracy:87.79%
# 5 4
# 2269343 1136549 1132794
# 42739/42739 [==============================] - 100s 2ms/step - loss: 195.2731 - accuracy: 0.7416
# 5 4
# Accuracy:74.16%
# 5 5
# 5 6
# 2269343 1136549 1132794
# 35699/35699 [==============================] - 83s 2ms/step - loss: 106.7450 - accuracy: 0.8751
# 5 6
# Accuracy:87.51%
# 5 7
# 2269343 1136549 1132794
# 35766/35766 [==============================] - 81s 2ms/step - loss: 107.9111 - accuracy: 0.8733
# 5 7
# Accuracy:87.33%
# 5 10
# 2269343 1136549 1132794
# 40484/40484 [==============================] - 92s 2ms/step - loss: 127.4267 - accuracy: 0.8199
# 5 10
# Accuracy:81.99%
# 5 11
# 2269343 1136549 1132794
# 35702/35702 [==============================] - 82s 2ms/step - loss: 106.5697 - accuracy: 0.8749
# 5 11
# Accuracy:87.49%
# 5 12
# 2269343 1136549 1132794
# 35565/35565 [==============================] - 83s 2ms/step - loss: 104.6512 - accuracy: 0.8782
# 5 12
# Accuracy:87.82%
# 5 14
# 2269343 1136549 1132794
# 35538/35538 [==============================] - 82s 2ms/step - loss: 104.6562 - accuracy: 0.8789
# 5 14
# Accuracy:87.89%
# Length of y_attack_test 5796
# 196
# XTRAIN_TRAINLEN 2272565 2272565
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               317568
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1776/1776 [==============================] - 76s 42ms/step - loss: 0.1793 - accuracy: 0.9240 - val_loss: 0.0561 - val_accuracy: 0.9976
# Epoch 2/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0760 - accuracy: 0.9764 - val_loss: 0.0466 - val_accuracy: 0.9979
# Epoch 3/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0686 - accuracy: 0.9794 - val_loss: 0.0373 - val_accuracy: 0.9990
# Epoch 4/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0625 - accuracy: 0.9814 - val_loss: 0.0426 - val_accuracy: 0.9986
# Epoch 5/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0583 - accuracy: 0.9827 - val_loss: 0.0587 - val_accuracy: 0.9966
# Epoch 6/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0555 - accuracy: 0.9836 - val_loss: 0.0382 - val_accuracy: 0.9959
# Epoch 7/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0512 - accuracy: 0.9851 - val_loss: 0.0368 - val_accuracy: 0.9959
# Epoch 8/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0467 - accuracy: 0.9864 - val_loss: 0.0363 - val_accuracy: 0.9976
# Epoch 9/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0439 - accuracy: 0.9875 - val_loss: 0.0618 - val_accuracy: 0.9969
# Epoch 10/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0467 - accuracy: 0.9867 - val_loss: 0.0247 - val_accuracy: 0.9981
# Epoch 11/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0433 - accuracy: 0.9878 - val_loss: 0.0197 - val_accuracy: 0.9990
# Epoch 12/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0406 - accuracy: 0.9888 - val_loss: 0.0181 - val_accuracy: 0.9985
# Epoch 13/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0387 - accuracy: 0.9894 - val_loss: 0.0218 - val_accuracy: 0.9986
# Epoch 14/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0353 - accuracy: 0.9905 - val_loss: 0.0165 - val_accuracy: 0.9983
# Epoch 15/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0366 - accuracy: 0.9902 - val_loss: 0.0177 - val_accuracy: 0.9988
# Epoch 16/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0350 - accuracy: 0.9907 - val_loss: 0.0123 - val_accuracy: 0.9997
# Epoch 17/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0332 - accuracy: 0.9911 - val_loss: 0.0162 - val_accuracy: 0.9990
# Epoch 18/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0323 - accuracy: 0.9915 - val_loss: 0.0150 - val_accuracy: 0.9997
# Epoch 19/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0326 - accuracy: 0.9914 - val_loss: 0.0229 - val_accuracy: 0.9972
# Epoch 20/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0322 - accuracy: 0.9917 - val_loss: 0.0107 - val_accuracy: 0.9995
# 6 1
# 2272565 1136549 1136016
# 35579/35579 [==============================] - 79s 2ms/step - loss: 0.3729 - accuracy: 0.9958
# 6 1
# Accuracy:99.58%
# 6 2
# 2272565 1136549 1136016
# 39518/39518 [==============================] - 91s 2ms/step - loss: 13.2511 - accuracy: 0.9025
# 6 2
# Accuracy:90.25%
# 6 3
# 2272565 1136549 1136016
# 35839/35839 [==============================] - 85s 2ms/step - loss: 0.8129 - accuracy: 0.9912
# 6 3
# Accuracy:99.12%
# 6 4
# 2272565 1136549 1136016
# 42739/42739 [==============================] - 97s 2ms/step - loss: 42.4704 - accuracy: 0.8290
# 6 4
# Accuracy:82.90%
# 6 5
# 2272565 1136549 1136016
# 35689/35689 [==============================] - 81s 2ms/step - loss: 0.4091 - accuracy: 0.9928
# 6 5
# Accuracy:99.28%
# 6 6
# 6 7
# 2272565 1136549 1136016
# 35766/35766 [==============================] - 82s 2ms/step - loss: 0.2710 - accuracy: 0.9906
# 6 7
# Accuracy:99.06%
# 6 10
# 2272565 1136549 1136016
# 40484/40484 [==============================] - 93s 2ms/step - loss: 17.8310 - accuracy: 0.8752
# 6 10
# Accuracy:87.52%
# 6 11
# 2272565 1136549 1136016
# 35702/35702 [==============================] - 81s 2ms/step - loss: 0.9960 - accuracy: 0.9924
# 6 11
# Accuracy:99.24%
# 6 12
# 2272565 1136549 1136016
# 35565/35565 [==============================] - 84s 2ms/step - loss: 0.0721 - accuracy: 0.9962
# 6 12
# Accuracy:99.62%
# 6 14
# 2272565 1136549 1136016
# 35538/35538 [==============================] - 82s 2ms/step - loss: 0.0195 - accuracy: 0.9970
# 6 14
# Accuracy:99.70%
# Length of y_attack_test 7938
# 143
# XTRAIN_TRAINLEN 2271683 2271683
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_6 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               317568
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1775/1775 [==============================] - 76s 42ms/step - loss: 0.1740 - accuracy: 0.9235 - val_loss: 0.0351 - val_accuracy: 0.9991
# Epoch 2/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0770 - accuracy: 0.9740 - val_loss: 0.0574 - val_accuracy: 0.9981
# Epoch 3/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0693 - accuracy: 0.9765 - val_loss: 0.0589 - val_accuracy: 0.9979
# Epoch 4/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0565 - accuracy: 0.9799 - val_loss: 0.0333 - val_accuracy: 0.9989
# Epoch 5/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0457 - accuracy: 0.9825 - val_loss: 0.0250 - val_accuracy: 0.9983
# Epoch 6/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0421 - accuracy: 0.9838 - val_loss: 0.0268 - val_accuracy: 0.9973
# Epoch 7/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0359 - accuracy: 0.9855 - val_loss: 0.0315 - val_accuracy: 0.9961
# Epoch 8/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0344 - accuracy: 0.9859 - val_loss: 0.0322 - val_accuracy: 0.9948
# Epoch 9/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0312 - accuracy: 0.9868 - val_loss: 0.0312 - val_accuracy: 0.9931
# Epoch 10/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0304 - accuracy: 0.9871 - val_loss: 0.0305 - val_accuracy: 0.9965
# Epoch 11/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0290 - accuracy: 0.9876 - val_loss: 0.0217 - val_accuracy: 0.9982
# Epoch 12/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0246 - accuracy: 0.9893 - val_loss: 0.0276 - val_accuracy: 0.9829
# Epoch 13/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0369 - accuracy: 0.9852 - val_loss: 0.0594 - val_accuracy: 0.9977
# Epoch 14/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0404 - accuracy: 0.9842 - val_loss: 0.0176 - val_accuracy: 0.9971
# Epoch 15/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0217 - accuracy: 0.9901 - val_loss: 0.0280 - val_accuracy: 0.9955
# Epoch 16/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0238 - accuracy: 0.9900 - val_loss: 0.0286 - val_accuracy: 0.9824
# Epoch 17/20
# 1775/1775 [==============================] - 74s 42ms/step - loss: 0.0247 - accuracy: 0.9892 - val_loss: 0.0159 - val_accuracy: 0.9986
# Epoch 18/20
# 1775/1775 [==============================] - 74s 42ms/step - loss: 0.0220 - accuracy: 0.9900 - val_loss: 0.0171 - val_accuracy: 0.9986
# Epoch 19/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0217 - accuracy: 0.9900 - val_loss: 0.0185 - val_accuracy: 0.9984
# Epoch 20/20
# 1775/1775 [==============================] - 75s 42ms/step - loss: 0.0204 - accuracy: 0.9905 - val_loss: 0.0222 - val_accuracy: 0.9976
# 7 1
# 2271683 1136549 1135134
# 35579/35579 [==============================] - 82s 2ms/step - loss: 1.4829 - accuracy: 0.9895
# 7 1
# Accuracy:98.95%
# 7 2
# 2271683 1136549 1135134
# 39518/39518 [==============================] - 88s 2ms/step - loss: 68.7133 - accuracy: 0.8908
# 7 2
# Accuracy:89.08%
# 7 3
# 2271683 1136549 1135134
# 35839/35839 [==============================] - 84s 2ms/step - loss: 3.8611 - accuracy: 0.9823
# 7 3
# Accuracy:98.23%
# 7 4
# 2271683 1136549 1135134
# 42739/42739 [==============================] - 101s 2ms/step - loss: 183.7802 - accuracy: 0.8237
# 7 4
# Accuracy:82.37%
# 7 5
# 2271683 1136549 1135134
# 35689/35689 [==============================] - 81s 2ms/step - loss: 1.2847 - accuracy: 0.9864
# 7 5
# Accuracy:98.64%
# 7 6
# 2271683 1136549 1135134
# 35699/35699 [==============================] - 81s 2ms/step - loss: 0.8989 - accuracy: 0.9861
# 7 6
# Accuracy:98.61%
# 7 7
# 7 10
# 2271683 1136549 1135134
# 40484/40484 [==============================] - 93s 2ms/step - loss: 12.4413 - accuracy: 0.8696
# 7 10
# Accuracy:86.96%
# 7 11
# 2271683 1136549 1135134
# 35702/35702 [==============================] - 83s 2ms/step - loss: 5.5524 - accuracy: 0.9861
# 7 11
# Accuracy:98.61%
# 7 12
# 2271683 1136549 1135134
# 35565/35565 [==============================] - 82s 2ms/step - loss: 0.2971 - accuracy: 0.9909
# 7 12
# Accuracy:99.09%
# 7 14
# 2271683 1136549 1135134
# 35538/35538 [==============================] - 81s 2ms/step - loss: 0.0403 - accuracy: 0.9911
# 7 14
# Accuracy:99.11%
# Length of y_attack_test 158930
# 7
# XTRAIN_TRAINLEN 2249059 2249059
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_7 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               317568
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1758/1758 [==============================] - 75s 42ms/step - loss: 0.1620 - accuracy: 0.9240 - val_loss: 0.0321 - val_accuracy: 0.9910
# Epoch 2/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0333 - accuracy: 0.9894 - val_loss: 0.0191 - val_accuracy: 0.9932
# Epoch 3/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0266 - accuracy: 0.9920 - val_loss: 0.0225 - val_accuracy: 0.9938
# Epoch 4/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0243 - accuracy: 0.9927 - val_loss: 0.0249 - val_accuracy: 0.9901
# Epoch 5/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0229 - accuracy: 0.9932 - val_loss: 0.0151 - val_accuracy: 0.9960
# Epoch 6/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0224 - accuracy: 0.9933 - val_loss: 0.0297 - val_accuracy: 0.9883
# Epoch 7/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0216 - accuracy: 0.9936 - val_loss: 0.0196 - val_accuracy: 0.9942
# Epoch 8/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0181 - accuracy: 0.9947 - val_loss: 0.0116 - val_accuracy: 0.9969
# Epoch 9/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0164 - accuracy: 0.9955 - val_loss: 0.0206 - val_accuracy: 0.9969
# Epoch 10/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0154 - accuracy: 0.9958 - val_loss: 0.0152 - val_accuracy: 0.9970
# Epoch 11/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0156 - accuracy: 0.9959 - val_loss: 0.0125 - val_accuracy: 0.9964
# Epoch 12/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0144 - accuracy: 0.9962 - val_loss: 0.0089 - val_accuracy: 0.9972
# Epoch 13/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0143 - accuracy: 0.9962 - val_loss: 0.0087 - val_accuracy: 0.9974
# Epoch 14/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0144 - accuracy: 0.9962 - val_loss: 0.0095 - val_accuracy: 0.9974
# Epoch 15/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0139 - accuracy: 0.9964 - val_loss: 0.0348 - val_accuracy: 0.9955
# Epoch 16/20
# 1758/1758 [==============================] - 74s 42ms/step - loss: 0.0138 - accuracy: 0.9964 - val_loss: 0.0092 - val_accuracy: 0.9974
# Epoch 17/20
# ...
# Epoch 8/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0232 - accuracy: 0.9922 - val_loss: 0.0181 - val_accuracy: 0.9914
# Epoch 9/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0211 - accuracy: 0.9929 - val_loss: 0.0169 - val_accuracy: 0.9931
# Epoch 10/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0201 - accuracy: 0.9933 - val_loss: 0.0144 - val_accuracy: 0.9932
# Epoch 11/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0182 - accuracy: 0.9941 - val_loss: 0.0127 - val_accuracy: 0.9937
# Epoch 12/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.0105 - val_accuracy: 0.9948
# Epoch 13/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.0096 - val_accuracy: 0.9949
# Epoch 14/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 0.0125 - val_accuracy: 0.9948
# Epoch 15/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0170 - accuracy: 0.9946 - val_loss: 0.0136 - val_accuracy: 0.9929
# Epoch 16/20
# 1773/1773 [==============================] - 74s 42ms/step - loss: 0.0151 - accuracy: 0.9952 - val_loss: 0.0080 - val_accuracy: 0.9953
# Epoch 17/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.0120 - val_accuracy: 0.9949
# Epoch 18/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0143 - accuracy: 0.9955 - val_loss: 0.0124 - val_accuracy: 0.9951
# Epoch 19/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.0096 - val_accuracy: 0.9953
# Epoch 20/20
# 1773/1773 [==============================] - 75s 42ms/step - loss: 0.0142 - accuracy: 0.9956 - val_loss: 0.0071 - val_accuracy: 0.9958
# 11 1
# 2268773 1136549 1132224
# 35579/35579 [==============================] - 85s 2ms/step - loss: 1.2165 - accuracy: 0.9172
# 11 1
# Accuracy:91.72%
# 11 2
# 2268773 1136549 1132224
# 39518/39518 [==============================] - 89s 2ms/step - loss: 8.5173 - accuracy: 0.8284
# 11 2
# Accuracy:82.84%
# 11 3
# 2268773 1136549 1132224
# 35839/35839 [==============================] - 81s 2ms/step - loss: 1.4098 - accuracy: 0.9108
# 11 3
# Accuracy:91.08%
# 11 4
# 2268773 1136549 1132224
# 42739/42739 [==============================] - 98s 2ms/step - loss: 51.1991 - accuracy: 0.8128
# 11 4
# Accuracy:81.28%
# 11 5
# 2268773 1136549 1132224
# 35689/35689 [==============================] - 82s 2ms/step - loss: 3.3801 - accuracy: 0.9146
# 11 5
# Accuracy:91.46%
# 11 6
# 2268773 1136549 1132224
# 35699/35699 [==============================] - 81s 2ms/step - loss: 2.5148 - accuracy: 0.9141
# 11 6
# Accuracy:91.41%
# 11 7
# 2268773 1136549 1132224
# 35766/35766 [==============================] - 81s 2ms/step - loss: 1.2636 - accuracy: 0.9123
# 11 7
# Accuracy:91.23%
# 11 10
# 2268773 1136549 1132224
# 40484/40484 [==============================] - 92s 2ms/step - loss: 4.2983 - accuracy: 0.8060
# 11 10
# Accuracy:80.60%
# 11 11
# 11 12
# 2268773 1136549 1132224
# 35565/35565 [==============================] - 84s 2ms/step - loss: 1.2566 - accuracy: 0.9176
# 11 12
# Accuracy:91.76%
# 11 14
# 2268773 1136549 1132224
# 35538/35538 [==============================] - 80s 2ms/step - loss: 1.2196 - accuracy: 0.9182
# 11 14
# Accuracy:91.82%
# Length of y_attack_test 1507
# 754
# XTRAIN_TRAINLEN 2272827 2272827
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_9 (Reshape)          (None, 31, 80)            0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 2480)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               317568
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1776/1776 [==============================] - 76s 42ms/step - loss: 0.1221 - accuracy: 0.9475 - val_loss: 0.0231 - val_accuracy: 0.9954
# Epoch 2/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0197 - accuracy: 0.9950 - val_loss: 0.0207 - val_accuracy: 0.9954
# Epoch 3/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0170 - accuracy: 0.9957 - val_loss: 0.0133 - val_accuracy: 0.9960
# Epoch 4/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0133 - accuracy: 0.9968 - val_loss: 0.0164 - val_accuracy: 0.9960
# Epoch 5/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0114 - accuracy: 0.9973 - val_loss: 0.0095 - val_accuracy: 0.9967
# Epoch 6/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0099 - accuracy: 0.9977 - val_loss: 0.0108 - val_accuracy: 0.9967
# Epoch 7/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0105 - accuracy: 0.9976 - val_loss: 0.0095 - val_accuracy: 0.9967
# Epoch 8/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0090 - accuracy: 0.9979 - val_loss: 0.0130 - val_accuracy: 0.9954
# Epoch 9/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0089 - accuracy: 0.9980 - val_loss: 0.0075 - val_accuracy: 0.9967
# Epoch 10/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9967
# Epoch 11/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0090 - accuracy: 0.9980 - val_loss: 0.0095 - val_accuracy: 0.9967
# Epoch 12/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0079 - accuracy: 0.9982 - val_loss: 0.0073 - val_accuracy: 0.9967
# Epoch 13/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0080 - accuracy: 0.9981 - val_loss: 0.0094 - val_accuracy: 0.9967
# Epoch 14/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0083 - accuracy: 0.9981 - val_loss: 0.0074 - val_accuracy: 0.9967
# Epoch 15/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0075 - accuracy: 0.9981 - val_loss: 0.0072 - val_accuracy: 0.9967
# Epoch 16/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.0076 - val_accuracy: 0.9967
# Epoch 17/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.0061 - val_accuracy: 0.9967
# Epoch 18/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0075 - accuracy: 0.9981 - val_loss: 0.0062 - val_accuracy: 0.9973
# Epoch 19/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0069 - val_accuracy: 0.9967
# Epoch 20/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0078 - accuracy: 0.9982 - val_loss: 0.0059 - val_accuracy: 0.9973
# 12 1
# 2272827 1136549 1136278
# 35579/35579 [==============================] - 82s 2ms/step - loss: 3.9324 - accuracy: 0.9562
# 12 1
# Accuracy:95.62%
# 12 2
# 2272827 1136549 1136278
# 39518/39518 [==============================] - 90s 2ms/step - loss: 84.7651 - accuracy: 0.8649
# 12 2
# Accuracy:86.49%
# 12 3
# 2272827 1136549 1136278
# 35839/35839 [==============================] - 84s 2ms/step - loss: 12.9774 - accuracy: 0.9542
# 12 3
# Accuracy:95.42%
# 12 4
# 2272827 1136549 1136278
# 42739/42739 [==============================] - 97s 2ms/step - loss: 348.3355 - accuracy: 0.8053
# 12 4
# Accuracy:80.53%
# 12 5
# 2272827 1136549 1136278
# 35689/35689 [==============================] - 83s 2ms/step - loss: 6.0100 - accuracy: 0.9534
# 12 5
# Accuracy:95.34%
# 12 6
# 2272827 1136549 1136278
# 35699/35699 [==============================] - 81s 2ms/step - loss: 6.8841 - accuracy: 0.9532
# 12 6
# Accuracy:95.32%
# 12 7
# 2272827 1136549 1136278
# 35766/35766 [==============================] - 84s 2ms/step - loss: 5.7599 - accuracy: 0.9512
# 12 7
# Accuracy:95.12%
# 12 10
# 2272827 1136549 1136278
# 40484/40484 [==============================] - 94s 2ms/step - loss: 22.1039 - accuracy: 0.8955
# 12 10
# Accuracy:89.55%
# 12 11
# 2272827 1136549 1136278
# 35702/35702 [==============================] - 83s 2ms/step - loss: 7.4227 - accuracy: 0.9529
# 12 11
# Accuracy:95.29%
# 12 12
# 12 14
# 2272827 1136549 1136278
# 35538/35538 [==============================] - 80s 2ms/step - loss: 3.2193 - accuracy: 0.9573
# 12 14
# Accuracy:95.73%
# Length of y_attack_test 652
# 1743
# XTRAIN_TRAINLEN 2272985 2272985
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_40 (Conv2D)           (None, 2, 37, 256)        1024
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 1, 35, 256)        393472
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 1, 35, 256)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 1, 33, 256)        196864
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 1, 33, 256)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1, 33, 256)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 1, 31, 80)         61520
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 31, 80)            0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 2480)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               317568
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 970,706
# Trainable params: 970,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1776/1776 [==============================] - 76s 42ms/step - loss: 0.1497 - accuracy: 0.9294 - val_loss: 0.0327 - val_accuracy: 0.9862
# Epoch 2/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0237 - accuracy: 0.9929 - val_loss: 0.0287 - val_accuracy: 0.9893
# Epoch 3/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0197 - accuracy: 0.9940 - val_loss: 0.0219 - val_accuracy: 0.9893
# Epoch 4/20
# 1776/1776 [==============================] - 74s 42ms/step - loss: 0.0177 - accuracy: 0.9946 - val_loss: 0.0217 - val_accuracy: 0.9893
# Epoch 5/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0168 - accuracy: 0.9949 - val_loss: 0.0133 - val_accuracy: 0.9923
# Epoch 6/20
# 1776/1776 [==============================] - 74s 42ms/step - loss: 0.0145 - accuracy: 0.9956 - val_loss: 0.0190 - val_accuracy: 0.9923
# Epoch 7/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0131 - accuracy: 0.9964 - val_loss: 0.0177 - val_accuracy: 0.9893
# Epoch 8/20
# 1776/1776 [==============================] - 76s 43ms/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.0112 - val_accuracy: 0.9954
# Epoch 9/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0113 - accuracy: 0.9969 - val_loss: 0.0089 - val_accuracy: 0.9954
# Epoch 10/20
# 1776/1776 [==============================] - 75s 43ms/step - loss: 0.0112 - accuracy: 0.9971 - val_loss: 0.0129 - val_accuracy: 0.9954
# Epoch 11/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0131 - accuracy: 0.9964 - val_loss: 0.0117 - val_accuracy: 0.9954
# Epoch 12/20
# 1776/1776 [==============================] - 75s 43ms/step - loss: 0.0126 - accuracy: 0.9968 - val_loss: 0.0088 - val_accuracy: 0.9954
# Epoch 13/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0097 - val_accuracy: 0.9954
# Epoch 14/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0102 - accuracy: 0.9973 - val_loss: 0.0114 - val_accuracy: 0.9954
# Epoch 15/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0102 - val_accuracy: 0.9954
# Epoch 16/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0103 - accuracy: 0.9973 - val_loss: 0.0066 - val_accuracy: 0.9954
# Epoch 17/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.0104 - val_accuracy: 0.9954
# Epoch 18/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 0.0124 - val_accuracy: 0.9954
# Epoch 19/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0103 - accuracy: 0.9972 - val_loss: 0.0081 - val_accuracy: 0.9954
# Epoch 20/20
# 1776/1776 [==============================] - 75s 42ms/step - loss: 0.0116 - accuracy: 0.9972 - val_loss: 0.0076 - val_accuracy: 0.9954
# 14 1
# 2272985 1136549 1136436
# 35579/35579 [==============================] - 83s 2ms/step - loss: 6.9981 - accuracy: 0.8384
# 14 1
# Accuracy:83.84%
# 14 2
# 2272985 1136549 1136436
# 39518/39518 [==============================] - 92s 2ms/step - loss: 24.7519 - accuracy: 0.7678
# 14 2
# Accuracy:76.78%
# 14 3
# 2272985 1136549 1136436
# 35839/35839 [==============================] - 82s 2ms/step - loss: 7.9108 - accuracy: 0.8348
# 14 3
# Accuracy:83.48%
# 14 4
# 2272985 1136549 1136436
# 42739/42739 [==============================] - 97s 2ms/step - loss: 97.3375 - accuracy: 0.6973
# 14 4
# Accuracy:69.73%
# 14 5
# 2272985 1136549 1136436
# 35689/35689 [==============================] - 83s 2ms/step - loss: 8.0967 - accuracy: 0.8349
# 14 5
# Accuracy:83.49%
# 14 6
# 2272985 1136549 1136436
# 35699/35699 [==============================] - 81s 2ms/step - loss: 9.1103 - accuracy: 0.8361
# 14 6
# Accuracy:83.61%
# 14 7
# 2272985 1136549 1136436
# 35766/35766 [==============================] - 83s 2ms/step - loss: 6.8950 - accuracy: 0.8364
# 14 7
# Accuracy:83.64%
# 14 10
# 2272985 1136549 1136436
# 40484/40484 [==============================] - 94s 2ms/step - loss: 6.4742 - accuracy: 0.8465
# 14 10
# Accuracy:84.65%
# 14 11
# 2272985 1136549 1136436
# 35702/35702 [==============================] - 82s 2ms/step - loss: 8.9563 - accuracy: 0.8370
# 14 11
# Accuracy:83.70%
# 14 12
# 2272985 1136549 1136436
# 35565/35565 [==============================] - 80s 2ms/step - loss: 6.4399 - accuracy: 0.8389
# 14 12
# Accuracy:83.89%
# 14 14

# %%
# Name of pickle file to be saved
outname = 'conf_matrix_basearch_all_full_balanced.pickle'

#outfile = os.path.join(os.getcwd(), outname)
if os.path.exists(path+outname):
        os.replace(path+outname, path+outname + ".old")
        
with open(path+outname, 'wb') as file:
    pickle.dump(cfs, file)

outname_diff='cf_diff.pickle'
with open(path+outname_diff,'wb') as file:
    pickle.dump(cfs_diff,file)

# %%
cfs, cfs_diff
# Out:
# ([array([[1115270,   21278],
#          [ 128027,       0]]),
#   array([[1115270,   21278],
#          [  10268,      25]]),
#   array([[1115270,   21278],
#          [ 230980,      93]]),
#   array([[1115270,   21278],
#          [   2712,    2787]]),
#   array([[1115270,   21278],
#          [   5723,      73]]),
#   array([[1115270,   21278],
#          [   6923,    1015]]),
#   array([[1115270,   21278],
#          [ 158777,     153]]),
#   array([[1115270,   21278],
#          [   5782,     115]]),
#   array([[1115270,   21278],
#          [   1507,       0]]),
#   array([[1115270,   21278],
#          [    652,       0]]),
#   array([[1133741,    2807],
#          [   1966,       0]]),
#   array([[1133741,    2807],
#          [   5460,    4833]]),
#   array([[1133741,    2807],
#          [ 216803,   14270]]),
#   array([[1133741,    2807],
#          [   5498,       1]]),
#   array([[1133741,    2807],
#          [   5795,       1]]),
#   array([[1133741,    2807],
#          [   7938,       0]]),
#   array([[1133741,    2807],
#          [ 158846,      84]]),
#   array([[1133741,    2807],
#          [   5897,       0]]),
#   array([[1133741,    2807],
#          [   1507,       0]]),
#   array([[1133741,    2807],
#          [    650,       2]]),
#   array([[1112163,   24385],
#          [   1966,       0]]),
#   array([[1112163,   24385],
#          [  35454,   92573]]),
#   array([[1112163,   24385],
#          [ 203568,   27505]]),
#   array([[1112163,   24385],
#          [   5461,      38]]),
#   array([[1112163,   24385],
#          [   5733,      63]]),
#   array([[1112163,   24385],
#          [   7938,       0]]),
#   array([[1112163,   24385],
#          [ 158853,      77]]),
#   array([[1112163,   24385],
#          [   5887,      10]]),
#   array([[1112163,   24385],
#          [   1458,      49]]),
#   array([[1112163,   24385],
#          [    645,       7]]),
#   array([[1136548,       0],
#          [   1966,       0]]),
#   array([[1136548,       0],
#          [ 128027,       0]]),
#   array([[1136548,       0],
#          [  10293,       0]]),
#   array([[1136548,       0],
#          [   5499,       0]]),
#   array([[1136548,       0],
#          [   5796,       0]]),
#   array([[1136548,       0],
#          [   7938,       0]]),
#   array([[1136548,       0],
#          [ 158930,       0]]),
#   array([[1136548,       0],
#          [   5897,       0]]),
#   array([[1136548,       0],
#          [   1507,       0]]),
#   array([[1136548,       0],
#          [    652,       0]]),
#   array([[1002181,  134367],
#          [   1966,       0]]),
#   array([[1002181,  134367],
#          [  68065,   59962]]),
#   array([[1002181,  134367],
#          [   2938,    7355]]),
#   array([[1002181,  134367],
#          [ 216257,   14816]]),
#   array([[1002181,  134367],
#          [   5633,     163]]),
#   array([[1002181,  134367],
#          [   7938,       0]]),
#   array([[1002181,  134367],
#          [  98502,   60428]]),
#   array([[1002181,  134367],
#          [   5858,      39]]),
#   array([[1002181,  134367],
#          [   1493,      14]]),
#   array([[1002181,  134367],
#          [    638,      14]]),
#   array([[1133771,    2777],
#          [   1966,       0]]),
#   array([[1133771,    2777],
#          [ 120514,    7513]]),
#   array([[1133771,    2777],
#          [   7275,    3018]]),
#   array([[1133771,    2777],
#          [ 231073,       0]]),
#   array([[1133771,    2777],
#          [   5499,       0]]),
#   array([[1133771,    2777],
#          [   7938,       0]]),
#   array([[1133771,    2777],
#          [ 158902,      28]]),
#   array([[1133771,    2777],
#          [   5897,       0]]),
#   array([[1133771,    2777],
#          [   1507,       0]]),
#   array([[1133771,    2777],
#          [    652,       0]]),
#   array([[1126518,   10030],
#          [   1966,       0]]),
#   array([[1126518,   10030],
#          [ 128027,       0]]),
#   array([[1126518,   10030],
#          [  10293,       0]]),
#   array([[1126518,   10030],
#          [ 231042,      31]]),
#   array([[1126518,   10030],
#          [   5497,       2]]),
#   array([[1126518,   10030],
#          [   5794,       2]]),
#   array([[1126518,   10030],
#          [ 158906,      24]]),
#   array([[1126518,   10030],
#          [   5897,       0]]),
#   array([[1126518,   10030],
#          [    301,    1206]]),
#   array([[1126518,   10030],
#          [     53,     599]]),
#   array([[976133, 160415],
#          [  1950,     16]]),
#   array([[976133, 160415],
#          [ 84351,  43676]]),
#   array([[976133, 160415],
#          [  2602,   7691]]),
#   array([[976133, 160415],
#          [216818,  14255]]),
#   array([[976133, 160415],
#          [  2409,   3090]]),
#   array([[976133, 160415],
#          [  3778,   2018]]),
#   array([[976133, 160415],
#          [  3964,   3974]]),
#   array([[976133, 160415],
#          [  2920,   2977]]),
#   array([[976133, 160415],
#          [   214,   1293]]),
#   array([[976133, 160415],
#          [    36,    616]]),
#   array([[1044135,   92413],
#          [   1804,     162]]),
#   array([[1044135,   92413],
#          [ 124642,    3385]]),
#   array([[1044135,   92413],
#          [   9909,     384]]),
#   array([[1044135,   92413],
#          [ 163633,   67440]]),
#   array([[1044135,   92413],
#          [   5133,     366]]),
#   array([[1044135,   92413],
#          [   5717,      79]]),
#   array([[1044135,   92413],
#          [   7921,      17]]),
#   array([[1044135,   92413],
#          [ 158869,      61]]),
#   array([[1044135,   92413],
#          [   1408,      99]]),
#   array([[1044135,   92413],
#          [    618,      34]]),
#   array([[1088618,   47930],
#          [   1966,       0]]),
#   array([[1088618,   47930],
#          [ 122905,    5122]]),
#   array([[1088618,   47930],
#          [   4580,    5713]]),
#   array([[1088618,   47930],
#          [ 218285,   12788]]),
#   array([[1088618,   47930],
#          [   5306,     193]]),
#   array([[1088618,   47930],
#          [   5584,     212]]),
#   array([[1088618,   47930],
#          [   7937,       1]]),
#   array([[1088618,   47930],
#          [  87404,   71526]]),
#   array([[1088618,   47930],
#          [   5871,      26]]),
#   array([[1088618,   47930],
#          [    639,      13]]),
#   array([[953297, 183251],
#          [   784,   1182]]),
#   array([[953297, 183251],
#          [110363,  17664]]),
#   array([[953297, 183251],
#          [  6264,   4029]]),
#   array([[953297, 183251],
#          [230755,    318]]),
#   array([[953297, 183251],
#          [  5288,    211]]),
#   array([[953297, 183251],
#          [  3924,   1872]]),
#   array([[953297, 183251],
#          [  3964,   3974]]),
#   array([[953297, 183251],
#          [ 15557, 143373]]),
#   array([[953297, 183251],
#          [  2920,   2977]]),
#   array([[953297, 183251],
#          [   144,   1363]])],
#  [array([[1127486,    9062],
#          [ 128023,       4]]),
#   array([[1127486,    9062],
#          [  10282,      11]]),
#   array([[1127486,    9062],
#          [ 230560,     513]]),
#   array([[1127486,    9062],
#          [   5431,      68]]),
#   array([[1127486,    9062],
#          [   5769,      27]]),
#   array([[1127486,    9062],
#          [   7899,      39]]),
#   array([[1127486,    9062],
#          [ 119224,   39706]]),
#   array([[1127486,    9062],
#          [   5841,      56]]),
#   array([[1127486,    9062],
#          [   1507,       0]]),
#   array([[1127486,    9062],
#          [    652,       0]]),
#   array([[1124050,   12498],
#          [   1966,       0]]),
#   array([[1124050,   12498],
#          [   6467,    3826]]),
#   array([[1124050,   12498],
#          [ 163704,   67369]]),
#   array([[1124050,   12498],
#          [   2878,    2621]]),
#   array([[1124050,   12498],
#          [   3370,    2426]]),
#   array([[1124050,   12498],
#          [   7826,     112]]),
#   array([[1124050,   12498],
#          [ 158018,     912]]),
#   array([[1124050,   12498],
#          [   5862,      35]]),
#   array([[1124050,   12498],
#          [   1500,       7]]),
#   array([[1124050,   12498],
#          [    649,       3]]),
#   array([[1134333,    2215],
#          [   1961,       5]]),
#   array([[1134333,    2215],
#          [  90426,   37601]]),
#   array([[1134333,    2215],
#          [ 184851,   46222]]),
#   array([[1134333,    2215],
#          [   3651,    1848]]),
#   array([[1134333,    2215],
#          [   4181,    1615]]),
#   array([[1134333,    2215],
#          [   7890,      48]]),
#   array([[1134333,    2215],
#          [ 158907,      23]]),
#   array([[1134333,    2215],
#          [   5873,      24]]),
#   array([[1134333,    2215],
#          [   1506,       1]]),
#   array([[1134333,    2215],
#          [    651,       1]]),
#   array([[1112363,   24185],
#          [   1909,      57]]),
#   array([[1112363,   24185],
#          [  77009,   51018]]),
#   array([[1112363,   24185],
#          [   5283,    5010]]),
#   array([[1112363,   24185],
#          [   3380,    2119]]),
#   array([[1112363,   24185],
#          [   3291,    2505]]),
#   array([[1112363,   24185],
#          [   7359,     579]]),
#   array([[1112363,   24185],
#          [ 158391,     539]]),
#   array([[1112363,   24185],
#          [   5767,     130]]),
#   array([[1112363,   24185],
#          [   1504,       3]]),
#   array([[1112363,   24185],
#          [    649,       3]]),
#   array([[1118802,   17746],
#          [   1876,      90]]),
#   array([[1118802,   17746],
#          [ 118728,    9299]]),
#   array([[1118802,   17746],
#          [   9449,     844]]),
#   array([[1118802,   17746],
#          [ 221278,    9795]]),
#   array([[1118802,   17746],
#          [   1443,    4353]]),
#   array([[1118802,   17746],
#          [   7509,     429]]),
#   array([[1118802,   17746],
#          [ 158399,     531]]),
#   array([[1118802,   17746],
#          [   5775,     122]]),
#   array([[1118802,   17746],
#          [   1369,     138]]),
#   array([[1118802,   17746],
#          [    649,       3]]),
#   array([[1113809,   22739],
#          [   1960,       6]]),
#   array([[1113809,   22739],
#          [ 118368,    9659]]),
#   array([[1113809,   22739],
#          [   9715,     578]]),
#   array([[1113809,   22739],
#          [ 223479,    7594]]),
#   array([[1113809,   22739],
#          [   2266,    3233]]),
#   array([[1113809,   22739],
#          [   6778,    1160]]),
#   array([[1113809,   22739],
#          [ 141875,   17055]]),
#   array([[1113809,   22739],
#          [   4598,    1299]]),
#   array([[1113809,   22739],
#          [   1503,       4]]),
#   array([[1113809,   22739],
#          [    647,       5]]),
#   array([[1117743,   18805],
#          [   1935,      31]]),
#   array([[1117743,   18805],
#          [ 125203,    2824]]),
#   array([[1117743,   18805],
#          [  10119,     174]]),
#   array([[1117743,   18805],
#          [ 221872,    9201]]),
#   array([[1117743,   18805],
#          [   5132,     367]]),
#   array([[1117743,   18805],
#          [   3480,    2316]]),
#   array([[1117743,   18805],
#          [ 152384,    6546]]),
#   array([[1117743,   18805],
#          [   5009,     888]]),
#   array([[1117743,   18805],
#          [   1495,      12]]),
#   array([[1117743,   18805],
#          [    648,       4]]),
#   array([[1089675,   46873],
#          [   1865,     101]]),
#   array([[1089675,   46873],
#          [ 126658,    1369]]),
#   array([[1089675,   46873],
#          [   9687,     606]]),
#   array([[1089675,   46873],
#          [ 221715,    9358]]),
#   array([[1089675,   46873],
#          [   5497,       2]]),
#   array([[1089675,   46873],
#          [   5321,     475]]),
#   array([[1089675,   46873],
#          [   7339,     599]]),
#   array([[1089675,   46873],
#          [   4670,    1227]]),
#   array([[1089675,   46873],
#          [   1504,       3]]),
#   array([[1089675,   46873],
#          [    650,       2]]),
#   array([[1127067,    9481],
#          [   1953,      13]]),
#   array([[1127067,    9481],
#          [ 127578,     449]]),
#   array([[1127067,    9481],
#          [  10022,     271]]),
#   array([[1127067,    9481],
#          [ 230704,     369]]),
#   array([[1127067,    9481],
#          [   4602,     897]]),
#   array([[1127067,    9481],
#          [   5177,     619]]),
#   array([[1127067,    9481],
#          [   6582,    1356]]),
#   array([[1127067,    9481],
#          [ 143795,   15135]]),
#   array([[1127067,    9481],
#          [   1500,       7]]),
#   array([[1127067,    9481],
#          [    651,       1]]),
#   array([[1135491,    1057],
#          [   1966,       0]]),
#   array([[1135491,    1057],
#          [ 127465,     562]]),
#   array([[1135491,    1057],
#          [  10267,      26]]),
#   array([[1135491,    1057],
#          [ 228341,    2732]]),
#   array([[1135491,    1057],
#          [   5497,       2]]),
#   array([[1135491,    1057],
#          [   5796,       0]]),
#   array([[1135491,    1057],
#          [   7937,       1]]),
#   array([[1135491,    1057],
#          [ 158927,       3]]),
#   array([[1135491,    1057],
#          [   5897,       0]]),
#   array([[1135491,    1057],
#          [     97,     555]]),
#   array([[1134600,    1948],
#          [   1966,       0]]),
#   array([[1134600,    1948],
#          [ 120979,    7048]]),
#   array([[1134600,    1948],
#          [   9689,     604]]),
#   array([[1134600,    1948],
#          [ 221526,    9547]]),
#   array([[1134600,    1948],
#          [   5498,       1]]),
#   array([[1134600,    1948],
#          [   5784,      12]]),
#   array([[1134600,    1948],
#          [   7936,       2]]),
#   array([[1134600,    1948],
#          [ 158497,     433]]),
#   array([[1134600,    1948],
#          [   5883,      14]]),
#   array([[1134600,    1948],
#          [    360,    1147]])])

# %%
with open(path+'cf_diff.pickle', 'rb') as file:
    cfs = pickle.load(file)

# %%
len(cfs)
# Out:
# 110

# %%
accuracy = []
attack_accuracy = []

for i in range(len(cfs)):
    accuracy.append(np.round(np.trace(cfs[i])/np.sum(cfs[i])*100,2))
    attack_accuracy.append(np.nan_to_num(np.round(cfs[i][1][1]/(cfs[i][0][1]+cfs[i][1][1])*100,2)))

# %%
attacks = [1,2,3,4,5,6,7,10,11,12,14]# Attacks that are retained
# Convert from 1D to 2D
numattacks = len(attacks)
accr = np.zeros((numattacks, numattacks))
attackaccr = np.zeros((numattacks, numattacks))

n = 0

for i in range(numattacks):
    for j in range(numattacks):
        if i == j:
            accr[i][j] = 100
            continue
        else:
            accr[i][j] = accuracy[n]
            attackaccr[i][j] = attack_accuracy[n]
            n = n + 1

# %%
# Create Datafeame and update row/column names
accrd = pd.DataFrame(accr)
ataccrd = pd.DataFrame(attackaccr)

#accrd.columns=accrmat.columns.values
accrd.columns=y_attacks
accrd.index=y_attacks
ataccrd.columns=y_attacks
ataccrd.index=y_attacks

# %%
fig = plt.figure(figsize=(10, 8), dpi=150)

plt.rcParams["font.family"] = "serif"
plt.rc('axes', titlesize=12)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=11)    # legend fontsize
plt.rc('axes', titlesize=15)  # fontsize of the figure title
# create some labels
attack_labels = [ "{0:d}".format(i) for i in attacks ]

# create a color map with random colors
#colmap = matplotlib.colors.ListedColormap(np.random.random((21,3)))
#colmap.colors[0] = [0,0,0]
import seaborn as sns
# this is the real plotting part
ax = fig.add_subplot(111)
sns.heatmap(accrd, linewidths=.5, annot=True, fmt='.2f', cmap='winter', ax=ax)


plt.xlabel('Test Attack')
plt.ylabel('Training Attack')
plt.title('Overall accuracy when training and testing with individual attacks')

plt.show()

# %%
fig = plt.figure(figsize=(10, 8), dpi=150)

plt.rcParams["font.family"] = "serif"
plt.rc('axes', titlesize=12)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=11)    # legend fontsize
plt.rc('axes', titlesize=15)  # fontsize of the figure title
# create some labels
attack_labels = [ "{0:d}".format(i) for i in attacks ]

# create a color map with random colors
#colmap = matplotlib.colors.ListedColormap(np.random.random((21,3)))
#colmap.colors[0] = [0,0,0]

# this is the real plotting part
ax = fig.add_subplot(111)
sns.heatmap(ataccrd, linewidths=.5, annot=True, fmt='.2f', cmap='winter', ax=ax)


plt.xlabel('Test Attack')
plt.ylabel('Training Attack')
plt.title('Attack Accuracy when training and testing with individual attacks (Second Run)')

plt.show()
